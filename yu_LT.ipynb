# %%
row = int(input("Enter number of rows: "))
print("<table>")
icol=1
x=1   
for table in range(row):
    color=(icol+1)%2
    if color==0:
        print('<tr class="lightyellowrow"><td>',x,'</td><td>',x**2,'</td></tr>',sep="")
    if color==1:
        print('<tr class="whiterow"><td>',x,'</td><td>',x**2,'</td></tr>',sep="")
    icol+=1
    x+=1
print("</table>")
# Out:
# Enter number of rows: 4
# <table>
# <tr class="lightyellowrow"><td>1</td><td>1</td></tr>
# <tr class="whiterow"><td>2</td><td>4</td></tr>
# <tr class="lightyellowrow"><td>3</td><td>9</td></tr>
# <tr class="whiterow"><td>4</td><td>16</td></tr>
# </table>

# %%
day = int(input("Enter day: "))
month = int(input("Enter month: "))
year = int(input("Enter year: "))

if year%4 == 0:
    if month > 0 and month < 13:
        if month == 2:
            if day > 0 and day < 30:
                date = True
            else:
                date = False
        elif month == 8:
            if day > 0 and day < 31:
                date = True
            else:
                date = False
        elif month %2 == 0:
            if day > 0 and day < 31:
                date = True
            else:
                date = False
        else:
            if day > 0 and day < 32:
                date = True
            else:
                date = False
    else:
        date = False
else:
    if month > 0 and month < 13:
        if month == 2:
            if day > 0 and day < 29:
                date = True
            else:
                date = False
        elif month == 8:
            if day > 0 and day < 31:
                date = True
            else:
                date = False
        elif month %2 == 0:
            if day > 0 and day < 31:
                date = True
            else:
                date = False
        else:
            if day > 0 and day < 32:
                date = True
            else:
                date = False
    else:
        date = False

if date == True:
    if day == 1:
        day = "1st"
    elif day == 2:
        day = "2nd"
    elif day == 3:
        day = "3rd"
    elif day == 21:
        day = "21st"
    elif day == 22:
        day = "22nd"
    elif day == 23:
        day = "23rd"
    elif day == 31:
        day = "31st"
    else:
        day = str(day) + "th"
    if month == 1:
        month = "January"
    elif month == 2:
        month = "February"
    elif month == 3:
        month = "March"
    elif month == 4:
        month = "April"
    elif month == 5:
        month = "May"
    elif month == 6:
        month = "June"
    elif month == 7:
        month = "July"
    elif month == 8:
        month = "August"
    elif month == 9:
        month = "September"
    elif month == 10:
        month = "October"
    elif month == 11:
        month = "November"
    elif month == 12:
        month = "December"
    print("It is the",day,"of the month of", month, "of the year", year)
else:
    print("Date is invalid.")
# Out:
# Enter day: 2
# Enter month: 2
# Enter year: 2
# It is the 2nd of the month of February of the year 2

# %%
def obedient(x):
    if x%3==0 and x>=6:
        return True
    else:
        return False
obedient(123)
# Out:
# True

# %%
def multtable(x):
    for i in range(1,x+1):
        for j in range(1,x+1):
            print(i*j, end="\t")           
        print()
multtable(8)
# Out:
# 1	2	3	4	5	6	7	8
# 2	4	6	8	10	12	14	16
# 3	6	9	12	15	18	21	24
# 4	8	12	16	20	24	28	32
# 5	10	15	20	25	30	35	40
# 6	12	18	24	30	36	42	48
# 7	14	21	28	35	42	49	56
# 8	16	24	32	40	48	56	64

# %%
fire=0
water=0
earth=0

while True:
    q_one=input("Do you prefer (a) the mountains, (b) the city, or (c) the beach?")
    if q_one=="a":
        fire+=1
        break
    if q_one=="b":
        earth+=1
        break
    if q_one=="c":
        water+=1
        break
    elif q_one !="a" or q_one !="b" or q_one !="c":
        print("Sorry, you inputted a wrong letter. Please start again.")
while True:
    q_two=input("Do you prefer (a) yoghurt, (b) ice cream , or (c) gelato?")
    if q_two=="a":
        earth+=1
        break
    if q_two=="b":
        water+=1
        break
    if q_two=="c":
        fire+=1
        break
    elif q_two !="a" or q_two !="b" or q_two !="c":
        print("Sorry, you inputted a wrong letter. Please start again.")
while True:
    q_three=input("Do you prefer (a) reading, (b) singing, or (c) writing?")
    if q_three=="a":
        water+=1
        break
    if q_three=="b":
        fire+=1
        break
    if q_three=="c":
        earth+=1
        break
    elif q_three !="a" or q_three !="b" or q_three !="c":
        print("Sorry, you inputted a wrong letter. Please start again.")
while True:
    q_four=input("Do you prefer (a) sweet, (b) salty, or (c) spicy food?")
    if q_four=="a":
        earth+=1
        break
    if q_four=="b":
        water+=1
        break
    if q_four=="c":
        fire+=1
        break
    elif q_four !="a" or q_four !="b" or q_four !="c":
        print("Sorry, you inputted a wrong letter. Please start again.")
while True:
    q_five=input("Do you prefer (a) cats, (b) dogs, or (c) fish?")
    if q_five=="a":
        earth+=1
        break
    if q_five=="b":
        fire+=1
        break
    if q_five=="c":
        water+=1
        break
    elif q_five !="a" or q_five !="b" or q_five !="c":
        print("Sorry, you inputted a wrong letter. Please start again.")
        
if fire>= water and fire> earth:
    element="Fire"
if water> fire and water>= earth:
    element="Water"
if earth>= fire and earth> water:
    element="Earth"
print("Your element is", element)
# Out:
# Do you prefer (a) the mountains, (b) the city, or (c) the beach?a
# Do you prefer (a) yoghurt, (b) ice cream , or (c) gelato?b
# Do you prefer (a) reading, (b) singing, or (c) writing?c
# Do you prefer (a) sweet, (b) salty, or (c) spicy food?d
# Sorry, you inputted a wrong letter. Please start again.
# Do you prefer (a) sweet, (b) salty, or (c) spicy food?e
# Sorry, you inputted a wrong letter. Please start again.
# Do you prefer (a) sweet, (b) salty, or (c) spicy food?d
# Sorry, you inputted a wrong letter. Please start again.
# Do you prefer (a) sweet, (b) salty, or (c) spicy food?a
# Do you prefer (a) cats, (b) dogs, or (c) fish?c
# Your element is Water
