# %% [markdown]
# ## End of Module 2
#
# #### Module 4

# %% [markdown]
# ### 0. Setup (Mini-Tutorial)
#
# **What is HTTP?**
#
# HTTP (or Hypertext Transfer Protocol) is a protocol which allows the fetching of resources, such as HTML or JSON documents. It is the foundation of any data exchange on the Web and it is a client-server protocol, which means requests are initiated by the recipient, usually the Web browser. A complete document is reconstructed from the different sub-documents fetched, for instance text, layout description, images, videos, scripts, and more.
#
# Source: [An Overview of HTTP (mozilla.org)](https://developer.mozilla.org/en-US/docs/Web/HTTP/Overview)
#
# **What is an Application Programming Interface (API)?**
#
# An application program interface (API) is a set of routines, protocols, and tools for building software applications. Basically, an API specifies how software components should interact. Additionally, APIs are used when programming graphical user interface (GUI) components.
#
# Source: [Webopedia](https://www.webopedia.com/TERM/A/API.html)

# %% [markdown]
# #### Python Requests Module
#
# Requests is a simple HTTP library for Python. The full documentation is found [here](https://requests.readthedocs.io/en/master/), but for this test, we don't need to go through the whole thing.
#
# To use it, simply import it.

# %%
# run this cell
import requests

# %% [markdown]
# For this setup, we use a simple API which generates 10 random jokes returned in JSON format.

# %%
# run this cell to check if you can call APIs

# First, determine the API URL
api_url = "https://official-joke-api.appspot.com/random_ten"

# Next, invoke the URL via requests.get(url)
data = requests.get(api_url)

# Let's inspect what requests.get() returns
print(data)
print(type(data))
# Out:
# <Response [200]>
# <class 'requests.models.Response'>

# %% [markdown]
# The call to requests.get(url) returns a **requests.models.Response** object. What you can see from above is the HTTP Response, and if everything is normal, the status code should be **200**.

# %%
type(data)
# Out:
# requests.models.Response

# %% [markdown]
# HTTP normally returns text which Python can then process as a string. The text body may be found in the Response's attribute **text**.

# %%
# run this cell

print(data.text)
# Out:
# [{"id":72,"type":"programming","setup":"I was gonna tell you a joke about UDP...","punchline":"...but you might not get it."},{"id":27,"type":"programming","setup":"['hip', 'hip']","punchline":"(hip hip array)"},{"id":55,"type":"general","setup":"Why is peter pan always flying?","punchline":"Because he neverlands"},{"id":221,"type":"general","setup":"What do you call a group of killer whales playing instruments?","punchline":"An Orca-stra."},{"id":377,"type":"programming","setup":"Knock-knock.","punchline":"A race condition. Who is there?"},{"id":199,"type":"general","setup":"What do I look like?","punchline":"A JOKE MACHINE!?"},{"id":94,"type":"general","setup":"Did you hear about the new restaurant on the moon?","punchline":"The food is great, but there’s just no atmosphere."},{"id":71,"type":"general","setup":"I couldn't get a reservation at the library...","punchline":"They were fully booked."},{"id":275,"type":"general","setup":"What type of music do balloons hate?","punchline":"Pop music!"},{"id":73,"type":"programming","setup":"The punchline often arrives before the set-up.","punchline":"Do you know the problem with UDP jokes?"}]

# %% [markdown]
# You should see a JSON Array of Jokes. A JSON Array looks like a Python List, but at this point, Python still treats it as a string. To process it in Python, you need to convert it to the equivalent advanced data type via the **json** module. Let's do that next and define the variable **jokes** to contain the data converted from JSON.

# %%
# run this cell

import json

jokes = json.loads(data.text)

print("Data:")
print(jokes)
print("Type:")
print(type(jokes))
# Out:
# Data:
# [{'id': 72, 'type': 'programming', 'setup': 'I was gonna tell you a joke about UDP...', 'punchline': '...but you might not get it.'}, {'id': 27, 'type': 'programming', 'setup': "['hip', 'hip']", 'punchline': '(hip hip array)'}, {'id': 55, 'type': 'general', 'setup': 'Why is peter pan always flying?', 'punchline': 'Because he neverlands'}, {'id': 221, 'type': 'general', 'setup': 'What do you call a group of killer whales playing instruments?', 'punchline': 'An Orca-stra.'}, {'id': 377, 'type': 'programming', 'setup': 'Knock-knock.', 'punchline': 'A race condition. Who is there?'}, {'id': 199, 'type': 'general', 'setup': 'What do I look like?', 'punchline': 'A JOKE MACHINE!?'}, {'id': 94, 'type': 'general', 'setup': 'Did you hear about the new restaurant on the moon?', 'punchline': 'The food is great, but there’s just no atmosphere.'}, {'id': 71, 'type': 'general', 'setup': "I couldn't get a reservation at the library...", 'punchline': 'They were fully booked.'}, {'id': 275, 'type': 'general', 'setup': 'What type of music do balloons hate?', 'punchline': 'Pop music!'}, {'id': 73, 'type': 'programming', 'setup': 'The punchline often arrives before the set-up.', 'punchline': 'Do you know the problem with UDP jokes?'}]
# Type:
# <class 'list'>

# %% [markdown]
# You can see from above that `jokes` is a list of dictionaries. Each dictionary will have various keys. Run the next cell to do a simple list comprehension operation on jokes, displaying the setup and punchline.

# %%
[j["setup"] + " " + j["punchline"] for j in jokes]
# Out:
# ['I was gonna tell you a joke about UDP... ...but you might not get it.',
#  "['hip', 'hip'] (hip hip array)",
#  'Why is peter pan always flying? Because he neverlands',
#  'What do you call a group of killer whales playing instruments? An Orca-stra.',
#  'Knock-knock. A race condition. Who is there?',
#  'What do I look like? A JOKE MACHINE!?',
#  'Did you hear about the new restaurant on the moon? The food is great, but there’s just no atmosphere.',
#  "I couldn't get a reservation at the library... They were fully booked.",
#  'What type of music do balloons hate? Pop music!',
#  'The punchline often arrives before the set-up. Do you know the problem with UDP jokes?']

# %% [markdown]
# ### 1 Financial Data API
#
#
# **(50 Points)**
#
# Stock Market Data
#
# IEX Cloud is a platform that makes financial data and services accessible to everyone.
#
# We shall be using their **sandbox** (playground) API environment for this test. If you wish to play around with real data, feel free to open an account with them at http://iexcloud.io. You will be issued an API token which you will then need to use in your API calls.
#
# For now, we are provided with a Sandbox Token.

# %%
# execute this cell
TOKEN="Tsk_b1e3203fb628428fb3f967dbd3dc2b0b"
finance_url="https://sandbox.iexapis.com/stable/tops?token={TOKEN}&symbols={TICKER}"

# %% [markdown]
# #### 1.1.
#
# Define a function `formatted_url` that accepts a stock symbol and returns the formatted URL call.
#
# Hint: use the string method `.format(...)` to be able to use the string template above work.

# %%
# define a function formatted_url that accepts a stock symbol and returns the formatted URL call


def formatted_url(symbol):
    # write function code below
    TOKEN="Tsk_b1e3203fb628428fb3f967dbd3dc2b0b"
    finance_url="https://sandbox.iexapis.com/stable/tops?token={}&symbols={}".format(TOKEN,symbol)
    return finance_url
    
# dump string below
print(formatted_url("AAPL"))
# Out:
# https://sandbox.iexapis.com/stable/tops?token=Tsk_b1e3203fb628428fb3f967dbd3dc2b0b&symbols=AAPL

# %% [markdown]
# #### 1.2.
#
# Test the API call with your URL.
#
# Sample output using Apple (AAPL) provided below. You may want to try other stock symbols like Amazon (AMZN), Google (GOOG), or Netflix (NFLX).
#
# **NOTE:** The prices below may be different from what you see depending on the time you made the request.

# %%
# write code 
api_url = "https://sandbox.iexapis.com/stable/tops?token=Tsk_b1e3203fb628428fb3f967dbd3dc2b0b&symbols=GOOG"
data2 = requests.get(api_url)
print(data)

# dump text attribute of your response object (here, we assume your variable name is data2)
data2.text
# Out:
# <Response [200]>
# '[{"symbol":"GOOG","sector":"ionshectlcrseogvey","securityType":"cs","bidPrice":0,"bidSize":0,"askPrice":0,"askSize":0,"lastUpdated":1599444216220,"lastSalePrice":1540.68,"lastSaleSize":101,"lastSaleTime":1602518811402,"volume":37439}]'

# %% [markdown]
# ### 1.2 Get a list of stocks
#
# Get stock prices of the following:
# * Apple (AAPL)
# * Amazon (AMZN)
# * Google (GOOG)
# * Netflix (NFLX)
#
# The symbols are already in the list variable `portfolio`.

# %%
# execute this code
portfolio = ["AAPL","AMZN","GOOG","NFLX"]

# %% [markdown]
# The URL format is like so:
#
# https://sandbox.iexapis.com/stable/stock/market/batch?symbols=aapl,fb&types=quotetoken=Tsk_b1e3203fb628428fb3f967dbd3dc2b0b

# %%
# execute this code
TOKEN="Tsk_b1e3203fb628428fb3f967dbd3dc2b0b"
market_url="https://sandbox.iexapis.com/stable/stock/market/batch?symbols={SYMBOLS}&types=quote&token={TOKEN}"

# %% [markdown]
# #### 1.2.
#
# Define a function `market_formatted_url` that accepts a **list of stock symbols** (similar to `portfolio`) and returns the formatted URL call.
#
# Hint: use the string method `.format(...)` to be able to use the string template above work.
# Hint: craft a string with comma-separated symbols based on the portfolio list.
# Hint: research on `str.join(list)` to generate a comma-separated string.

# %%
# write code below
def market_formatted_url(symbols):
    # write the rest of the function code below
    TOKEN="Tsk_b1e3203fb628428fb3f967dbd3dc2b0b"
    market_url="https://sandbox.iexapis.com/stable/stock/market/batch?symbols={}&types=quote&token={}".format(",".join(symbols),TOKEN)
    return market_url
    
# dump string below
print(market_formatted_url(portfolio))
# Out:
# https://sandbox.iexapis.com/stable/stock/market/batch?symbols=AAPL,AMZN,GOOG,NFLX&types=quote&token=Tsk_b1e3203fb628428fb3f967dbd3dc2b0b

# %% [markdown]
# #### 1.3.
#
# Retrieve the API data using `portfolio`.

# %%
# write code to call the API here
# Hint: use your new function market_formatted_url. 
# Hint: pass the portfolio list already defined for you.

market_data = requests.get(market_formatted_url(portfolio))

# Dump the text attribute of the response object. Sample output provided below (assuming you name your response variable market_data)
market_data.text
# Out:
# '{"AAPL":{"quote":{"symbol":"AAPL","companyName":"Apple, Inc.","primaryExchange":"NQDAAS","calculationPrice":"close","open":null,"openTime":null,"openSource":"iafilcof","close":null,"closeTime":null,"closeSource":"fciaofli","high":null,"highTime":1663841200046,"highSource":"iepn dc edieu5let 1amry","low":null,"lowTime":1611517906698,"lowSource":"dea peniil 1cdtr 5eemyu","latestPrice":386.53,"latestSource":"Close","latestTime":"July 28, 2020","latestUpdate":1656895171008,"latestVolume":null,"iexRealtimePrice":373.99,
0,"iexBidSize":0,"iexAskPrice":0,"iexAskSize":0,"iexOpen":null,"iexOpenTime":null,"iexClose":1524.9,"iexCloseTime":1635433372059,"marketCap":1042169543560,"peRatio":30.38,"week52High":1655.51,"week52Low":1063.5,"ytdChange":0.086806,"lastTradeTime":1622888947896,"isUSMarketOpen":false}},"NFLX":{"quote":{"symbol":"NFLX","companyName":"Netflix, Inc.","primaryExchange":"DNAASQ","calculationPrice":"close","open":null,"openTime":null,"openSource":"lfoifica","close":null,"closeTime":null,"closeSource":"aoilffic"," ...

# %% [markdown]
# #### 1.4.
#
# Load the JSON string into a variable named `market_quotes`.

# %%
import json

# write code here
# Hint: what attribute of the response object contains the JSON string?
market_quotes = json.loads(market_data.text)


# dump market_quotes (interactive mode). Sample output below
market_quotes
# Out:
# {'AAPL': {'quote': {'symbol': 'AAPL',
#    'companyName': 'Apple, Inc.',
#    'primaryExchange': 'NQDAAS',
#    'calculationPrice': 'close',
#    'open': None,
#    'openTime': None,
#    'openSource': 'iafilcof',
#    'close': None,
#    'closeTime': None,
#    'closeSource': 'fciaofli',
#    'high': None,
#    'highTime': 1663841200046,
#    'highSource': 'iepn dc edieu5let 1amry',
#    'low': None,
#    'lowTime': 1611517906698,
#    'lowSource': 'dea peniil 1cdtr 5eemyu',
#    'latestPrice': 386.53,
#    'latestSource': 'Close',
#    'latestTime': 'July 28, 2020',
#    'latestUpdate': 1656895171008,
#    'latestVolume': None,
#    'iexRealtimePrice': 373.99,
#    'iexRealtimeSize': 4,
#    'iexLastUpdated': 1667151383471,
#    'delayedPrice': None,
#    'delayedPriceTime': None,
#    'oddLotDelayedPrice': None,
#    'oddLotDelayedPriceTime': None,
#    'extendedPrice': None,
#    'extendedChange': None,
#    'extendedChangePercent': None,
#    'extendedPriceTime': None,
#    'previousClose': 395.96,
#    'previousVolume': 30765000,
#    'change': -6.34,
#    'changePercent': -0.01671,
#    'volume': None,
#    'iexMarketPercent': 0.005949609313059389,
#    'iexVolume': 155422,
#    'avgTotalVolume': 35966922,
#    'iexBidPrice': 0,
#    'iexBidSize': 0,
#    'iexAskPrice': 0,
#    'iexAskSize': 0,
#    'iexOpen': None,
#    'iexOpenTime': None,
#    'iexClose': 381.23,
#    'iexCloseTime': 1656959683707,
#    'marketCap': 1620541760035,
#    'peRatio': 30,
#    'week52High': 417.88,
#    'week52Low': 199.77,
#    'ytdChange': 0.25184,
#    'lastTradeTime': 1633244545546,
#    'isUSMarketOpen': False}},
#  'AMZN': {'quote': {'symbol': 'AMZN',
#    'companyName': 'Amazon.com, Inc.',
#    'primaryExchange': 'NDSAAQ',
#    'calculationPrice': 'close',
#    'open': None,
#    'openTime': None,
#    'openSource': 'iolfciaf',
#    'close': None,
#    'closeTime': None,
#    'closeSource': 'lficoiaf',
#    'high': None,
#    'highTime': 1665628050240,
#    'highSource': ' uatc 5ypd1ldire nemeei',
#    'low': None,
#    'lowTime': 1674595863209,
#    'lowSource': 'ny5ee ptdcrid 1emaleu i',
#    'latestPrice': 3134.43,
#    'latestSource': 'Close',
#    'latestTime': 'July 28, 2020',
#    'latestUpdate': 1672973320976,
#    'latestVolume': None,
#    'iexRealtimePrice': 3051,
#    'iexRealtimeSize': 104,
#    'iexLastUpdated': 1672276233156,
#    'delayedPrice': None,
#    'delayedPriceTime': None,
#    'oddLotDelayedPrice': None,
#    'oddLotDelayedPriceTime': None,
#    'extendedPrice': None,
#    'extendedChange': None,
#    'extendedChangePercent': None,
#    'extendedPriceTime': None,
#    'previousClose': 3095.98,
#    'previousVolume': 4363397,
#    'change': -55.17,
#    'changePercent': -0.01809,
#    'volume': None,
#    'iexMarketPercent': 0.012566731793360557,
#    'iexVolume': 38749,
#    'avgTotalVolume': 5300688,
#    'iexBidPrice': 0,
#    'iexBidSize': 0,
#    'iexAskPrice': 0,
#    'iexAskSize': 0,
#    'iexOpen': None,
#    'iexOpenTime': None,
#    'iexClose': 3092.73,
#    'iexCloseTime': 1597503759846,
#    'marketCap': 1523766540703,
#    'peRatio': 147.12,
#    'week52High': 3423.58,
#    'week52Low': 1655.38,
#    'ytdChange': 0.580741,
#    'lastTradeTime': 1614950641802,
#    'isUSMarketOpen': False}},
#  'GOOG': {'quote': {'symbol': 'GOOG',
#    'companyName': 'Alphabet, Inc.',
#    'primaryExchange': 'NSQAAD',
#    'calculationPrice': 'close',
#    'open': None,
#    'openTime': None,
#    'openSource': 'caofliif',
#    'close': None,
#    'closeTime': None,
#    'closeSource': 'ifcoialf',
#    'high': None,
#    'highTime': 1626663088799,
#    'highSource': 'a 1tiiden 5yecde mlurep',
#    'low': None,
#    'lowTime': 1606243678733,
#    'lowSource': ' eu5eer1iym ddepaltcn i',
#    'latestPrice': 1517.46,
#    'latestSource': 'Close',
#    'latestTime': 'July 28, 2020',
#    'latestUpdate': 1601476702921,
#    'latestVolume': None,
#    'iexRealtimePrice': 1564.03,
#    'iexRealtimeSize': 102,
#    'iexLastUpdated': 1618623102429,
#    'delayedPrice': None,
#    'delayedPriceTime': None,
#    'oddLotDelayedPrice': None,
#    'oddLotDelayedPriceTime': None,
#    'extendedPrice': None,
#    'extendedChange': None,
#    'extendedChangePercent': None,
#    'extendedPriceTime': None,
#    'previousClose': 1551.6,
#    'previousVolume': 1289785,
#    'change': -31.15,
#    'changePercent': -0.02,
#    'volume': None,
#    'iexMarketPercent': 0.022368280679797122,
#    'iexVolume': 36185,
#    'avgTotalVolume': 1774999,
#    'iexBidPrice': 0,
#    'iexBidSize': 0,
#    'iexAskPrice': 0,
#    'iexAskSize': 0,
#    'iexOpen': None,
#    'iexOpenTime': None,
#    'iexClose': 1524.9,
#    'iexCloseTime': 1635433372059,
#    'marketCap': 1042169543560,
#    'peRatio': 30.38,
#    'week52High': 1655.51,
#    'week52Low': 1063.5,
#    'ytdChange': 0.086806,
#    'lastTradeTime': 1622888947896,
#    'isUSMarketOpen': False}},
#  'NFLX': {'quote': {'symbol': 'NFLX',
#    'companyName': 'Netflix, Inc.',
#    'primaryExchange': 'DNAASQ',
#    'calculationPrice': 'close',
#    'open': None,
#    'openTime': None,
#    'openSource': 'lfoifica',
#    'close': None,
#    'closeTime': None,
#    'closeSource': 'aoilffic',
#    'high': None,
#    'highTime': 1651267663028,
#    'highSource': '1p5rat i nul emicdeeyed',
#    'low': None,
#    'lowTime': 1599857959772,
#    'lowSource': 'c  te e5enyr1iaipemuddl',
#    'latestPrice': 512.32,
#    'latestSource': 'Close',
#    'latestTime': 'July 28, 2020',
#    'latestUpdate': 1644313684981,
#    'latestVolume': None,
#    'iexRealtimePrice': 500.19,
#    'iexRealtimeSize': 51,
#    'iexLastUpdated': 1663676934073,
#    'delayedPrice': None,
#    'delayedPriceTime': None,
#    'oddLotDelayedPrice': None,
#    'oddLotDelayedPriceTime': None,
#    'extendedPrice': None,
#    'extendedChange': None,
#    'extendedChangePercent': None,
#    'extendedPriceTime': None,
#    'previousClose': 497.91,
#    'previousVolume': 8043322,
#    'change': -7.33,
#    'changePercent': -0.01448,
#    'volume': None,
#    'iexMarketPercent': 0.008919547947628927,
#    'iexVolume': 53792,
#    'avgTotalVolume': 9190212,
#    'iexBidPrice': 0,
#    'iexBidSize': 0,
#    'iexAskPrice': 0,
#    'iexAskSize': 0,
#    'iexOpen': None,
#    'iexOpenTime': None,
#    'iexClose': 490.09,
#    'iexCloseTime': 1636449337257,
#    'marketCap': 224098872279,
#    'peRatio': 83.31,
#    'week52High': 602.2,
#    'week52Low': 255.79,
#    'ytdChange': 0.46309,
#    'lastTradeTime': 1656320583207,
#    'isUSMarketOpen': False}}}

# %% [markdown]
# #### 1.5.
#
# Output the Last Price (`latestPrice`) per Symbol like so:

# %%
# Write code here. Sample output provided below but may vary depending on the time you made the request.
# No need to define a function for this step.

for i in market_quotes:
    print(i, "\t", market_quotes[i]["quote"]["latestPrice"])
# Out:
# AAPL 	 386.53
# AMZN 	 3134.43
# GOOG 	 1517.46
# NFLX 	 512.32

# %% [markdown]
# Hints:
# - use a tab ("\t") between the symbol and the price

# %% [markdown]
# ### 2 Social Listenening
#
# **(50 points)**

# %% [markdown]
# Social listening is the monitoring of a brand, a personality, a cause, or an idea for feedback, direct mentions of entities involved, sentiments, and discussions regarding related keywords (or hashtags), topics, competitors, haters, or industries, followed by an analysis of this data to gain further insights and actionable next steps.

# %% [markdown]
# Before we go to the questions, here are a few things not yet taught in class that you will use in your solutions.

# %% [markdown]
# Sorting lists using `sort()`
#
# Say you have the following list:

# %%
# execute this cell

demolist = ['D','A','F','B','E','C']

# %% [markdown]
# Use `sort()` to put elements in order in the **same** list.

# %%
# execute this cell 

demolist.sort()
print(demolist)
# Out:
# ['A', 'B', 'C', 'D', 'E', 'F']

# %% [markdown]
# But supposing you have a list consisting of elements with advanced data types, say, tuples...

# %%
demolist2 = [('A',59),('B',100),('C',20),('D',88),('E',25),('F',38)]

# %% [markdown]
# ... and you wish to sort this list by the number in the second element of each tuple in descending order.
#
# You use `sort()` with two parameters:
# * `key` indicates the the function that returns the value that will serve as basis for sorting
# * `reverse` takes on a boolean value (default is False) to specify whether the list will be in ascending or descending order
#
# To sort demolist2 by the number indicated as the second element of each tuple, and in descending order, execute the following cell.

# %%
# execute this cell

demolist2.sort(key=lambda x: x[1], reverse=True)
print(demolist2)
# Out:
# [('B', 100), ('D', 88), ('A', 59), ('F', 38), ('E', 25), ('C', 20)]

# %% [markdown]
# Note that I used lambda above but nothing is stopping you from defining a full-blown function like so:

# %%
demolist2 = [('A',59),('B',100),('C',20),('D',88),('E',25),('F',38)]

def sort_tuple(x):
    return x[1]

# note that you only pass the function reference (without the parentheses and parameters)
demolist2.sort(key=sort_tuple, reverse=True)
print(demolist2)
# Out:
# [('B', 100), ('D', 88), ('A', 59), ('F', 38), ('E', 25), ('C', 20)]

# %% [markdown]
# ### 2.1
#
# Consider a Twitter search for 100 tweets (which is the limit of Twitter) using the keyword "SONA". The resulting JSON dump from the Twitter API call has been pre-saved in the file named `tweets.json`. Let's load the file and convert the JSON string into a list of dictionaries of tweets.

# %%
# execute this cell to load the file
tweets_file = 'tweets.json'

with open("tweets.json","r") as json_file:
    tweets = json.loads(json_file.read())

# Dump contents of tweets to make sure things are okay.
tweets
# Out:
# [{'created_at': 'Tue Jul 28 03:25:35 +0000 2020',
#   'id': 1287952316029521920,
#   'id_str': '1287952316029521920',
#   'full_text': 'RT @watchmejayjay: Ay di ka nakanood ng SONA? Wag ka mag-alala, ito yung summary ng mga plano ni tatay laban sa COVID 19: A thread',
#   'truncated': False,
#   'display_text_range': [0, 130],
#   'entities': {'hashtags': [],
#    'symbols': [],
#    'user_mentions': [{'screen_name': 'watchmejayjay',
#      'name': 'Kuya Sir #JUNKTERRORLAWNOW',
#      'id': 2148463897,
#      'id_str': '2148463897',
#      'indices': [3, 17]}],
#    'urls': []},
#   'metadata': {'iso_language_code': 'tl', 'result_type': 'recent'},
#   'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#   'in_reply_to_status_id': None,
#   'in_reply_to_status_id_str': None,
#   'in_reply_to_user_id': None,
#   'in_reply_to_user_id_str': None,
#   'in_reply_to_screen_name': None,
#   'user': {'id': 1334271631,
#    'id_str': '1334271631',
#    'name': 'kai',
#    'screen_name': '_kyladel',
#    'location': 'Alaska',
#    'description': 'yessir i listen to hayley kiyoko',
#    'url': None,
#    'entities': {'description': {'urls': []}},
#    'protected': False,
#    'followers_count': 1490,
#    'friends_count': 551,
#    'listed_count': 3,
#    'created_at': 'Sun Apr 07 14:38:46 +0000 2013',
#    'favourites_count': 46915,
#    'utc_offset': None,
#    'time_zone': None,
#    'geo_enabled': True,
#    'verified': False,
#    'statuses_count': 74517,
#    'lang': None,
#    'contributors_enabled': False,
#    'is_translator': False,
#    'is_translation_enabled': False,
#    'profile_background_color': 'FFFFFF',
#    'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#    'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#    'profile_background_tile': True,
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/1260618870752079873/ul8OMYqw_normal.jpg',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1260618870752079873/ul8OMYqw_normal.jpg',
#    'profile_banner_url': 'https://pbs.twimg.com/profile_banners/1334271631/1589814512',
#    'profile_link_color': '000000',
#    'profile_sidebar_border_color': '000000',
#    'profile_sidebar_fill_color': 'FFFFFF',
#    'profile_text_color': '000000',
#    'profile_use_background_image': True,
#    'has_extended_profile': False,
#    'default_profile': False,
#    'default_profile_image': False,
#    'following': False,
#    'follow_request_sent': False,
#    'notifications': False,
#    'translator_type': 'none'},
#   'geo': None,
#   'coordinates': None,
#   'place': None,
#   'contributors': None,
#   'retweeted_status': {'created_at': 'Mon Jul 27 11:10:15 +0000 2020',
#    'id': 1287706865581752321,
#    'id_str': '1287706865581752321',
#    'full_text': 'Ay di ka nakanood ng SONA? Wag ka mag-alala, ito yung summary ng mga plano ni tatay laban sa COVID 19: A thread',
#    'truncated': False,
#    'display_text_range': [0, 111],
#    'entities': {'hashtags': [],
#     'symbols': [],
#     'user_mentions': [],
#     'urls': []},
#    'metadata': {'iso_language_code': 'tl', 'result_type': 'recent'},
#    'source': '<a href="https://mobile.twitter.com" rel="nofollow">Twitter Web App</a>',
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'in_reply_to_screen_name': None,
#    'user': {'id': 2148463897,
#     'id_str': '2148463897',
#     'name': 'Kuya Sir #JUNKTERRORLAWNOW',
#     'screen_name': 'watchmejayjay',
#     'location': '',
#     'description': "I'm not your Bio teacher",
#     'url': None,
#     'entities': {'description': {'urls': []}},
#     'protected': False,
#     'followers_count': 1128,
#     'friends_count': 388,
#     'listed_count': 0,
#     'created_at': 'Tue Oct 22 06:34:00 +0000 2013',
#     'favourites_count': 6250,
#     'utc_offset': None,
#     'time_zone': None,
#     'geo_enabled': False,
#     'verified': False,
#     'statuses_count': 5642,
#     'lang': None,
#     'contributors_enabled': False,
#     'is_translator': False,
#     'is_translation_enabled': False,
#     'profile_background_color': '000000',
#     'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#     'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#     'profile_background_tile': False,
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/1228894653329461249/em22Su2h_normal.png',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1228894653329461249/em22Su2h_normal.png',
#     'profile_banner_url': 'https://pbs.twimg.com/profile_banners/2148463897/1567167364',
#     'profile_link_color': '1B95E0',
#     'profile_sidebar_border_color': '000000',
#     'profile_sidebar_fill_color': '000000',
#     'profile_text_color': '000000',
#     'profile_use_background_image': False,
#     'has_extended_profile': False,
#     'default_profile': False,
#     'default_profile_image': False,
#     'following': False,
#     'follow_request_sent': False,
#     'notifications': False,
#     'translator_type': 'none'},
#    'geo': None,
#    'coordinates': None,
#    'place': None,
#    'contributors': None,
#    'is_quote_status': False,
#    'retweet_count': 366,
#    'favorite_count': 2037,
#    'favorited': False,
#    'retweeted': False,
#    'lang': 'tl'},
#   'is_quote_status': False,
#   'retweet_count': 366,
#   'favorite_count': 0,
#   'favorited': False,
#   'retweeted': False,
#   'lang': 'tl'},
#  {'created_at': 'Tue Jul 28 03:25:35 +0000 2020',
#   'id': 1287952315115122688,
#   'id_str': '1287952315115122688',
#   'full_text': 'RT @TOWER_Namba: 【#ジェジュン】\n\n\\カバーアルバムを引っさげたツアー映像🎥/\n\nツアー映像『J-JUN LIVE 2019～Love Covers～』本日入荷しました🙌\n2日間のみのプレミアムライヴを映像とCDでお楽しみいただける豪華盤!!!\n\nCDがあれば…',
#   'truncated': False,
#   'display_text_range': [0, 140],
#   'entities': {'hashtags': [{'text': 'ジェジュン', 'indices': [18, 24]}],
#    'symbols': [],
#    'user_mentions': [{'screen_name': 'TOWER_Namba',
#      'name': 'タワーレコード難波店',
#      'id': 202531712,
#      'id_str': '202531712',
#      'indices': [3, 15]}],
#    'urls': []},
#   'metadata': {'iso_language_code': 'ja', 'result_type': 'recent'},
#   'source': '<a href="http://twitter.com/download/android" rel="nofollow">Twitter for Android</a>',
#   'in_reply_to_status_id': None,
#   'in_reply_to_status_id_str': None,
#   'in_reply_to_user_id': None,
#   'in_reply_to_user_id_str': None,
#   'in_reply_to_screen_name': None,
#   'user': {'id': 4677397604,
#    'id_str': '4677397604',
#    'name': 'sona💚jj🎼☮️',
#    'screen_name': 'jj_sona_080506',
#    'location': 'Tokyo 🗼',
#    'description': '💚Only JJ💚ジェジュンに出逢えて同じ時代を生きれることに感謝🍀いつもジェジュンを照らす光の一粒でいたい✨見守り･想い･応援し…その人生を見届けたい🍀JAEFANS*🎀運命共同体🍀@bornfreeonekiss @JJ_information 🌸',
#    'url': None,
#    'entities': {'description': {'urls': []}},
#    'protected': False,
#    'followers_count': 250,
#    'friends_count': 211,
#    'listed_count': 1,
#    'created_at': 'Wed Dec 30 09:44:47 +0000 2015',
#    'favourites_count': 65844,
#    'utc_offset': None,
#    'time_zone': None,
#    'geo_enabled': False,
#    'verified': False,
#    'statuses_count': 108679,
#    'lang': None,
#    'contributors_enabled': False,
#    'is_translator': False,
#    'is_translation_enabled': False,
#    'profile_background_color': 'F5F8FA',
#    'profile_background_image_url': None,
#    'profile_background_image_url_https': None,
#    'profile_background_tile': False,
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/1250791897141874688/1-7zH_2i_normal.jpg',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1250791897141874688/1-7zH_2i_normal.jpg',
#    'profile_banner_url': 'https://pbs.twimg.com/profile_banners/4677397604/1594663098',
#    'profile_link_color': '1DA1F2',
#    'profile_sidebar_border_color': 'C0DEED',
#    'profile_sidebar_fill_color': 'DDEEF6',
#    'profile_text_color': '333333',
#    'profile_use_background_image': True,
#    'has_extended_profile': False,
#    'default_profile': True,
#    'default_profile_image': False,
#    'following': False,
#    'follow_request_sent': False,
#    'notifications': False,
#    'translator_type': 'none'},
#   'geo': None,
#   'coordinates': None,
#   'place': None,
#   'contributors': None,
#   'retweeted_status': {'created_at': 'Tue Jul 28 02:38:13 +0000 2020',
#    'id': 1287940394638962688,
#    'id_str': '1287940394638962688',
#    'full_text': '【#ジェジュン】\n\n\\カバーアルバムを引っさげたツアー映像🎥/\n\nツアー映像『J-JUN LIVE 2019～Love Covers～』本日入荷しました🙌\n2日間のみのプレミアムライヴを映像とCDでお楽しみいただける豪華盤!!!\n\nCDがあれば通勤・通学中、どこでもライヴを楽しめちゃいますね♪\n\n#J_JUN #김재중 #JAEFANS https://t.co/JXjLYYaCHF',
#    'truncated': False,
#    'display_text_range': [0, 169],
#    'entities': {'hashtags': [{'text': 'ジェジュン', 'indices': [1, 7]},
#      {'text': 'J_JUN', 'indices': [149, 155]},
#      {'text': '김재중', 'indices': [156, 160]},
#      {'text': 'JAEFANS', 'indices': [161, 169]}],
#     'symbols': [],
#     'user_mentions': [],
#     'urls': [],
#     'media': [{'id': 1287940360354664449,
#       'id_str': '1287940360354664449',
#       'indices': [170, 193],
#       'media_url': 'http://pbs.twimg.com/media/Ed-u7xbUEAEi69x.jpg',
#       'media_url_https': 'https://pbs.twimg.com/media/Ed-u7xbUEAEi69x.jpg',
#       'url': 'https://t.co/JXjLYYaCHF',
#       'display_url': 'pic.twitter.com/JXjLYYaCHF',
#       'expanded_url': 'https://twitter.com/TOWER_Namba/status/1287940394638962688/photo/1',
#       'type': 'photo',
#       'sizes': {'medium': {'w': 640, 'h': 480, 'resize': 'fit'},
#        'large': {'w': 640, 'h': 480, 'resize': 'fit'},
#        'thumb': {'w': 150, 'h': 150, 'resize': 'crop'},
#        'small': {'w': 640, 'h': 480, 'resize': 'fit'}}}]},
#    'extended_entities': {'media': [{'id': 1287940360354664449,
#       'id_str': '1287940360354664449',
#       'indices': [170, 193],
#       'media_url': 'http://pbs.twimg.com/media/Ed-u7xbUEAEi69x.jpg',
#       'media_url_https': 'https://pbs.twimg.com/media/Ed-u7xbUEAEi69x.jpg',
#       'url': 'https://t.co/JXjLYYaCHF',
#       'display_url': 'pic.twitter.com/JXjLYYaCHF',
#       'expanded_url': 'https://twitter.com/TOWER_Namba/status/1287940394638962688/photo/1',
#       'type': 'photo',
#       'sizes': {'medium': {'w': 640, 'h': 480, 'resize': 'fit'},
#        'large': {'w': 640, 'h': 480, 'resize': 'fit'},
#        'thumb': {'w': 150, 'h': 150, 'resize': 'crop'},
#        'small': {'w': 640, 'h': 480, 'resize': 'fit'}}}]},
#    'metadata': {'iso_language_code': 'ja', 'result_type': 'recent'},
#    'source': '<a href="https://mobile.twitter.com" rel="nofollow">Twitter Web App</a>',
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'in_reply_to_screen_name': None,
#    'user': {'id': 202531712,
#     'id_str': '202531712',
#     'name': 'タワーレコード難波店',
#     'screen_name': 'TOWER_Namba',
#     'location': '大阪府大阪市中央区難波千日前 12-22 難波センタービル',
#     'description': '大阪ミナミにありますタワーレコード難波店です。 お薦めの音楽情報、お得なセール・キャンペーン情報、インストアイベント情報などつぶやきます。 皆様のフォローお待ちしております。',
#     'url': 'https://t.co/gHx6bbmaKm',
#     'entities': {'url': {'urls': [{'url': 'https://t.co/gHx6bbmaKm',
#         'expanded_url': 'http://tower.jp/store/Namba',
#         'display_url': 'tower.jp/store/Namba',
#         'indices': [0, 23]}]},
#      'description': {'urls': []}},
#     'protected': False,
#     'followers_count': 35673,
#     'friends_count': 18657,
#     'listed_count': 500,
#     'created_at': 'Thu Oct 14 07:28:28 +0000 2010',
#     'favourites_count': 745,
#     'utc_offset': None,
#     'time_zone': None,
#     'geo_enabled': True,
#     'verified': False,
#     'statuses_count': 71006,
#     'lang': None,
#     'contributors_enabled': False,
#     'is_translator': False,
#     'is_translation_enabled': False,
#     'profile_background_color': 'FDCF00',
#     'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#     'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#     'profile_background_tile': False,
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/1212603681968807936/oRnKxI_n_normal.png',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1212603681968807936/oRnKxI_n_normal.png',
#     'profile_banner_url': 'https://pbs.twimg.com/profile_banners/202531712/1590484881',
#     'profile_link_color': 'D7000E',
#     'profile_sidebar_border_color': '000000',
#     'profile_sidebar_fill_color': 'F0F0F0',
#     'profile_text_color': '676767',
#     'profile_use_background_image': True,
#     'has_extended_profile': True,
#     'default_profile': False,
#     'default_profile_image': False,
#     'following': False,
#     'follow_request_sent': False,
#     'notifications': False,
#     'translator_type': 'none'},
#    'geo': None,
#    'coordinates': None,
#    'place': None,
#    'contributors': None,
#    'is_quote_status': False,
#    'retweet_count': 45,
#    'favorite_count': 32,
#    'favorited': False,
#    'retweeted': False,
#    'possibly_sensitive': False,
#    'lang': 'ja'},
#   'is_quote_status': False,
#   'retweet_count': 45,
#   'favorite_count': 0,
#   'favorited': False,
#   'retweeted': False,
#   'lang': 'ja'},
#  {'created_at': 'Tue Jul 28 03:25:34 +0000 2020',
#   'id': 1287952311357067266,
#   'id_str': '1287952311357067266',
#   'full_text': '@kapilkolotya @kharaa_sona_ Bhai jo le liya hai mene 3saal pehle usko me Boycott kr duga. But\n\nMujy Made in india IPHONE dedo.',
#   'truncated': False,
#   'display_text_range': [28, 126],
#   'entities': {'hashtags': [],
#    'symbols': [],
#    'user_mentions': [{'screen_name': 'kapilkolotya',
#      'name': 'passenger💮',
#      'id': 4872214153,
#      'id_str': '4872214153',
#      'indices': [0, 13]},
#     {'screen_name': 'kharaa_sona_',
#      'name': 'सोना Oro🥺🌸',
#      'id': 1134385217005744128,
#      'id_str': '1134385217005744128',
#      'indices': [14, 27]}],
#    'urls': []},
#   'metadata': {'iso_language_code': 'hi', 'result_type': 'recent'},
#   'source': '<a href="http://twitter.com/download/android" rel="nofollow">Twitter for Android</a>',
#   'in_reply_to_status_id': 1287949879520632837,
#   'in_reply_to_status_id_str': '1287949879520632837',
#   'in_reply_to_user_id': 4872214153,
#   'in_reply_to_user_id_str': '4872214153',
#   'in_reply_to_screen_name': 'kapilkolotya',
#   'user': {'id': 3106742457,
#    'id_str': '3106742457',
#    'name': '|| ठंडा-PAY-जल ||',
#    'screen_name': 'oreoganesh',
#    'location': 'BTW☝️',
#    'description': '|| Chai♥️ || music || Deep thinker || Rajsthani || Your mirror || Sad || bla bla bla.......\n.\nपैसे के यार है यहां सभी🤗',
#    'url': None,
#    'entities': {'description': {'urls': []}},
#    'protected': False,
#    'followers_count': 793,
#    'friends_count': 586,
#    'listed_count': 0,
#    'created_at': 'Mon Mar 23 05:12:02 +0000 2015',
#    'favourites_count': 19538,
#    'utc_offset': None,
#    'time_zone': None,
#    'geo_enabled': False,
#    'verified': False,
#    'statuses_count': 12538,
#    'lang': None,
#    'contributors_enabled': False,
#    'is_translator': False,
#    'is_translation_enabled': False,
#    'profile_background_color': 'C0DEED',
#    'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#    'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#    'profile_background_tile': False,
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/1287217868321390593/zN9DVnuq_normal.jpg',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1287217868321390593/zN9DVnuq_normal.jpg',
#    'profile_banner_url': 'https://pbs.twimg.com/profile_banners/3106742457/1595866446',
#    'profile_link_color': '1DA1F2',
#    'profile_sidebar_border_color': 'C0DEED',
#    'profile_sidebar_fill_color': 'DDEEF6',
#    'profile_text_color': '333333',
#    'profile_use_background_image': True,
#    'has_extended_profile': False,
#    'default_profile': True,
#    'default_profile_image': False,
#    'following': False,
#    'follow_request_sent': False,
#    'notifications': False,
#    'translator_type': 'none'},
#   'geo': None,
#   'coordinates': None,
#   'place': None,
#   'contributors': None,
#   'is_quote_status': False,
#   'retweet_count': 0,
#   'favorite_count': 0,
#   'favorited': False,
#   'retweeted': False,
#   'lang': 'hi'},
#  {'created_at': 'Tue Jul 28 03:25:30 +0000 2020',
#   'id': 1287952295192170496,
#   'id_str': '1287952295192170496',
#   'full_text': 'RT @TOWER_Namba: 【#ジェジュン】\n\n\\ジェジュンの優しく、深い歌声がしみわたる..../\n\nカバーアルバム『Love Covers Ⅱ』本日入荷しました🙌\n原曲の良さをひきたてるだけでなく、ジェジュンらしさも全開のアルバムです♪\n\n🎁タワレコ特典はアナザージャ…',
#   'truncated': False,
#   'display_text_range': [0, 140],
#   'entities': {'hashtags': [{'text': 'ジェジュン', 'indices': [18, 24]}],
#    'symbols': [],
#    'user_mentions': [{'screen_name': 'TOWER_Namba',
#      'name': 'タワーレコード難波店',
#      'id': 202531712,
#      'id_str': '202531712',
#      'indices': [3, 15]}],
#    'urls': []},
#   'metadata': {'iso_language_code': 'ja', 'result_type': 'recent'},
#   'source': '<a href="http://twitter.com/download/android" rel="nofollow">Twitter for Android</a>',
#   'in_reply_to_status_id': None,
#   'in_reply_to_status_id_str': None,
#   'in_reply_to_user_id': None,
#   'in_reply_to_user_id_str': None,
#   'in_reply_to_screen_name': None,
#   'user': {'id': 4677397604,
#    'id_str': '4677397604',
#    'name': 'sona💚jj🎼☮️',
#    'screen_name': 'jj_sona_080506',
#    'location': 'Tokyo 🗼',
#    'description': '💚Only JJ💚ジェジュンに出逢えて同じ時代を生きれることに感謝🍀いつもジェジュンを照らす光の一粒でいたい✨見守り･想い･応援し…その人生を見届けたい🍀JAEFANS*🎀運命共同体🍀@bornfreeonekiss @JJ_information 🌸',
#    'url': None,
#    'entities': {'description': {'urls': []}},
#    'protected': False,
#    'followers_count': 250,
#    'friends_count': 211,
#    'listed_count': 1,
#    'created_at': 'Wed Dec 30 09:44:47 +0000 2015',
#    'favourites_count': 65844,
#    'utc_offset': None,
#    'time_zone': None,
#    'geo_enabled': False,
#    'verified': False,
#    'statuses_count': 108679,
#    'lang': None,
#    'contributors_enabled': False,
#    'is_translator': False,
#    'is_translation_enabled': False,
#    'profile_background_color': 'F5F8FA',
#    'profile_background_image_url': None,
#    'profile_background_image_url_https': None,
#    'profile_background_tile': False,
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/1250791897141874688/1-7zH_2i_normal.jpg',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1250791897141874688/1-7zH_2i_normal.jpg',
#    'profile_banner_url': 'https://pbs.twimg.com/profile_banners/4677397604/1594663098',
#    'profile_link_color': '1DA1F2',
#    'profile_sidebar_border_color': 'C0DEED',
#    'profile_sidebar_fill_color': 'DDEEF6',
#    'profile_text_color': '333333',
#    'profile_use_background_image': True,
#    'has_extended_profile': False,
#    'default_profile': True,
#    'default_profile_image': False,
#    'following': False,
#    'follow_request_sent': False,
#    'notifications': False,
#    'translator_type': 'none'},
#   'geo': None,
#   'coordinates': None,
#   'place': None,
#   'contributors': None,
#   'retweeted_status': {'created_at': 'Tue Jul 28 02:37:30 +0000 2020',
#    'id': 1287940214426447872,
#    'id_str': '1287940214426447872',
#    'full_text': '【#ジェジュン】\n\n\\ジェジュンの優しく、深い歌声がしみわたる..../\n\nカバーアルバム『Love Covers Ⅱ』本日入荷しました🙌\n原曲の良さをひきたてるだけでなく、ジェジュンらしさも全開のアルバムです♪\n\n🎁タワレコ特典はアナザージャケット（TOWER RECORDS絵柄)です💕\n\n#J_JUN #김재중 #JAEFANS https://t.co/ZNn85uKVjW',
#    'truncated': False,
#    'display_text_range': [0, 167],
#    'entities': {'hashtags': [{'text': 'ジェジュン', 'indices': [1, 7]},
#      {'text': 'J_JUN', 'indices': [147, 153]},
#      {'text': '김재중', 'indices': [154, 158]},
#      {'text': 'JAEFANS', 'indices': [159, 167]}],
#     'symbols': [],
#     'user_mentions': [],
#     'urls': [],
#     'media': [{'id': 1287940184625954816,
#       'id_str': '1287940184625954816',
#       'indices': [168, 191],
#       'media_url': 'http://pbs.twimg.com/media/Ed-uxiyUwAACaar.jpg',
#       'media_url_https': 'https://pbs.twimg.com/media/Ed-uxiyUwAACaar.jpg',
#       'url': 'https://t.co/ZNn85uKVjW',
#       'display_url': 'pic.twitter.com/ZNn85uKVjW',
#       'expanded_url': 'https://twitter.com/TOWER_Namba/status/1287940214426447872/photo/1',
#       'type': 'photo',
#       'sizes': {'thumb': {'w': 150, 'h': 150, 'resize': 'crop'},
#        'medium': {'w': 480, 'h': 640, 'resize': 'fit'},
#        'small': {'w': 480, 'h': 640, 'resize': 'fit'},
#        'large': {'w': 480, 'h': 640, 'resize': 'fit'}}}]},
#    'extended_entities': {'media': [{'id': 1287940184625954816,
#       'id_str': '1287940184625954816',
#       'indices': [168, 191],
#       'media_url': 'http://pbs.twimg.com/media/Ed-uxiyUwAACaar.jpg',
#       'media_url_https': 'https://pbs.twimg.com/media/Ed-uxiyUwAACaar.jpg',
#       'url': 'https://t.co/ZNn85uKVjW',
#       'display_url': 'pic.twitter.com/ZNn85uKVjW',
#       'expanded_url': 'https://twitter.com/TOWER_Namba/status/1287940214426447872/photo/1',
#       'type': 'photo',
#       'sizes': {'thumb': {'w': 150, 'h': 150, 'resize': 'crop'},
#        'medium': {'w': 480, 'h': 640, 'resize': 'fit'},
#        'small': {'w': 480, 'h': 640, 'resize': 'fit'},
#        'large': {'w': 480, 'h': 640, 'resize': 'fit'}}}]},
#    'metadata': {'iso_language_code': 'ja', 'result_type': 'recent'},
#    'source': '<a href="https://mobile.twitter.com" rel="nofollow">Twitter Web App</a>',
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'in_reply_to_screen_name': None,
#    'user': {'id': 202531712,
#     'id_str': '202531712',
#     'name': 'タワーレコード難波店',
#     'screen_name': 'TOWER_Namba',
#     'location': '大阪府大阪市中央区難波千日前 12-22 難波センタービル',
#     'description': '大阪ミナミにありますタワーレコード難波店です。 お薦めの音楽情報、お得なセール・キャンペーン情報、インストアイベント情報などつぶやきます。 皆様のフォローお待ちしております。',
#     'url': 'https://t.co/gHx6bbmaKm',
#     'entities': {'url': {'urls': [{'url': 'https://t.co/gHx6bbmaKm',
#         'expanded_url': 'http://tower.jp/store/Namba',
#         'display_url': 'tower.jp/store/Namba',
#         'indices': [0, 23]}]},
#      'description': {'urls': []}},
#     'protected': False,
#     'followers_count': 35673,
#     'friends_count': 18657,
#     'listed_count': 500,
#     'created_at': 'Thu Oct 14 07:28:28 +0000 2010',
#     'favourites_count': 745,
#     'utc_offset': None,
#     'time_zone': None,
#     'geo_enabled': True,
#     'verified': False,
#     'statuses_count': 71006,
#     'lang': None,
#     'contributors_enabled': False,
#     'is_translator': False,
#     'is_translation_enabled': False,
#     'profile_background_color': 'FDCF00',
#     'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#     'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#     'profile_background_tile': False,
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/1212603681968807936/oRnKxI_n_normal.png',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1212603681968807936/oRnKxI_n_normal.png',
#     'profile_banner_url': 'https://pbs.twimg.com/profile_banners/202531712/1590484881',
#     'profile_link_color': 'D7000E',
#     'profile_sidebar_border_color': '000000',
#     'profile_sidebar_fill_color': 'F0F0F0',
#     'profile_text_color': '676767',
#     'profile_use_background_image': True,
#     'has_extended_profile': True,
#     'default_profile': False,
#     'default_profile_image': False,
#     'following': False,
#     'follow_request_sent': False,
#     'notifications': False,
#     'translator_type': 'none'},
#    'geo': None,
#    'coordinates': None,
#    'place': None,
#    'contributors': None,
#    'is_quote_status': False,
#    'retweet_count': 52,
#    'favorite_count': 43,
#    'favorited': False,
#    'retweeted': False,
#    'possibly_sensitive': False,
#    'lang': 'ja'},
#   'is_quote_status': False,
#   'retweet_count': 52,
#   'favorite_count': 0,
#   'favorited': False,
#   'retweeted': False,
#   'lang': 'ja'},
#  {'created_at': 'Tue Jul 28 03:25:29 +0000 2020',
#   'id': 1287952289915797504,
#   'id_str': '1287952289915797504',
#   'full_text': 'RT @JaDineTrash: Her own time. \nHer own thoughts. \nHer own style. \n\nThank you, Nadine. The battles you fight have always been for a bigger…',
#   'truncated': False,
#   'display_text_range': [0, 139],
#   'entities': {'hashtags': [],
#    'symbols': [],
#    'user_mentions': [{'screen_name': 'JaDineTrash',
#      'name': 'Remember Always',
#      'id': 4289604404,
#      'id_str': '4289604404',
#      'indices': [3, 15]}],
#    'urls': []},
#   'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#   'source': '<a href="http://twitter.com/download/android" rel="nofollow">Twitter for Android</a>',
#   'in_reply_to_status_id': None,
#   'in_reply_to_status_id_str': None,
#   'in_reply_to_user_id': None,
#   'in_reply_to_user_id_str': None,
#   'in_reply_to_screen_name': None,
#   'user': {'id': 552579717,
#    'id_str': '552579717',
#    'name': 'MaeAnn',
#    'screen_name': 'MissmaeAnn',
#    'location': '',
#    'description': 'I will do the work that a failure will not do.',
#    'url': None,
#    'entities': {'description': {'urls': []}},
#    'protected': False,
#    'followers_count': 1040,
#    'friends_count': 220,
#    'listed_count': 3,
#    'created_at': 'Fri Apr 13 07:19:24 +0000 2012',
#    'favourites_count': 51303,
#    'utc_offset': None,
#    'time_zone': None,
#    'geo_enabled': False,
#    'verified': False,
#    'statuses_count': 26127,
#    'lang': None,
#    'contributors_enabled': False,
#    'is_translator': False,
#    'is_translation_enabled': False,
#    'profile_background_color': 'F768E9',
#    'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#    'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#    'profile_background_tile': True,
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/827301907848781824/ce7W_fbn_normal.jpg',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/827301907848781824/ce7W_fbn_normal.jpg',
#    'profile_banner_url': 'https://pbs.twimg.com/profile_banners/552579717/1353199123',
#    'profile_link_color': '050505',
#    'profile_sidebar_border_color': 'C0DEED',
#    'profile_sidebar_fill_color': 'DDEEF6',
#    'profile_text_color': '333333',
#    'profile_use_background_image': True,
#    'has_extended_profile': False,
#    'default_profile': False,
#    'default_profile_image': False,
#    'following': False,
#    'follow_request_sent': False,
#    'notifications': False,
#    'translator_type': 'none'},
#   'geo': None,
#   'coordinates': None,
#   'place': None,
#   'contributors': None,
#   'retweeted_status': {'created_at': 'Mon Jul 27 12:38:18 +0000 2020',
#    'id': 1287729020625465346,
#    'id_str': '1287729020625465346',
#    'full_text': 'Her own time. \nHer own thoughts. \nHer own style. \n\nThank you, Nadine. The battles you fight have always been for a bigger cause. \n\nGandang pambanlaw sa nakakarimarim at ampaw na SONA. https://t.co/MnsaJZOvHS',
#    'truncated': False,
#    'display_text_range': [0, 183],
#    'entities': {'hashtags': [],
#     'symbols': [],
#     'user_mentions': [],
#     'urls': [],
#     'media': [{'id': 1287728999146414084,
#       'id_str': '1287728999146414084',
#       'indices': [184, 207],
#       'media_url': 'http://pbs.twimg.com/media/Ed7us7kXYAQdyVA.jpg',
#       'media_url_https': 'https://pbs.twimg.com/media/Ed7us7kXYAQdyVA.jpg',
#       'url': 'https://t.co/MnsaJZOvHS',
#       'display_url': 'pic.twitter.com/MnsaJZOvHS',
#       'expanded_url': 'https://twitter.com/JaDineTrash/status/1287729020625465346/photo/1',
#       'type': 'photo',
#       'sizes': {'thumb': {'w': 150, 'h': 150, 'resize': 'crop'},
#        'large': {'w': 1124, 'h': 1668, 'resize': 'fit'},
#        'medium': {'w': 809, 'h': 1200, 'resize': 'fit'},
#        'small': {'w': 458, 'h': 680, 'resize': 'fit'}}}]},
#    'extended_entities': {'media': [{'id': 1287728999146414084,
#       'id_str': '1287728999146414084',
#       'indices': [184, 207],
#       'media_url': 'http://pbs.twimg.com/media/Ed7us7kXYAQdyVA.jpg',
#       'media_url_https': 'https://pbs.twimg.com/media/Ed7us7kXYAQdyVA.jpg',
#       'url': 'https://t.co/MnsaJZOvHS',
#       'display_url': 'pic.twitter.com/MnsaJZOvHS',
#       'expanded_url': 'https://twitter.com/JaDineTrash/status/1287729020625465346/photo/1',
#       'type': 'photo',
#       'sizes': {'thumb': {'w': 150, 'h': 150, 'resize': 'crop'},
#        'large': {'w': 1124, 'h': 1668, 'resize': 'fit'},
#        'medium': {'w': 809, 'h': 1200, 'resize': 'fit'},
#        'small': {'w': 458, 'h': 680, 'resize': 'fit'}}},
#      {'id': 1287728999133843456,
#       'id_str': '1287728999133843456',
#       'indices': [184, 207],
#       'media_url': 'http://pbs.twimg.com/media/Ed7us7hXkAAB6fL.jpg',
#       'media_url_https': 'https://pbs.twimg.com/media/Ed7us7hXkAAB6fL.jpg',
#       'url': 'https://t.co/MnsaJZOvHS',
#       'display_url': 'pic.twitter.com/MnsaJZOvHS',
#       'expanded_url': 'https://twitter.com/JaDineTrash/status/1287729020625465346/photo/1',
#       'type': 'photo',
#       'sizes': {'thumb': {'w': 150, 'h': 150, 'resize': 'crop'},
#        'small': {'w': 461, 'h': 680, 'resize': 'fit'},
#        'large': {'w': 694, 'h': 1024, 'resize': 'fit'},
#        'medium': {'w': 694, 'h': 1024, 'resize': 'fit'}}}]},
#    'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#    'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'in_reply_to_screen_name': None,
#    'user': {'id': 4289604404,
#     'id_str': '4289604404',
#     'name': 'Remember Always',
#     'screen_name': 'JaDineTrash',
#     'location': 'Hyun Bin’s dimples',
#     'description': 'It’s time. #OustDuterteNow!',
#     'url': None,
#     'entities': {'description': {'urls': []}},
#     'protected': False,
#     'followers_count': 10468,
#     'friends_count': 115,
#     'listed_count': 12,
#     'created_at': 'Thu Nov 19 12:06:16 +0000 2015',
#     'favourites_count': 54031,
#     'utc_offset': None,
#     'time_zone': None,
#     'geo_enabled': True,
#     'verified': False,
#     'statuses_count': 54741,
#     'lang': None,
#     'contributors_enabled': False,
#     'is_translator': False,
#     'is_translation_enabled': False,
#     'profile_background_color': 'C0DEED',
#     'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#     'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#     'profile_background_tile': False,
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/1270014342830780417/7DG6HL08_normal.jpg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1270014342830780417/7DG6HL08_normal.jpg',
#     'profile_banner_url': 'https://pbs.twimg.com/profile_banners/4289604404/1567006556',
#     'profile_link_color': '1DA1F2',
#     'profile_sidebar_border_color': 'C0DEED',
#     'profile_sidebar_fill_color': 'DDEEF6',
#     'profile_text_color': '333333',
#     'profile_use_background_image': True,
#     'has_extended_profile': False,
#     'default_profile': True,
#     'default_profile_image': False,
#     'following': False,
#     'follow_request_sent': False,
#     'notifications': False,
#     'translator_type': 'none'},
#    'geo': None,
#    'coordinates': None,
#    'place': None,
#    'contributors': None,
#    'is_quote_status': False,
#    'retweet_count': 66,
#    'favorite_count': 236,
#    'favorited': False,
#    'retweeted': False,
#    'possibly_sensitive': False,
#    'lang': 'en'},
#   'is_quote_status': False,
#   'retweet_count': 66,
#   'favorite_count': 0,
#   'favorited': False,
#   'retweeted': False,
#   'lang': 'en'},
#  {'created_at': 'Tue Jul 28 03:25:27 +0000 2020',
#   'id': 1287952280218513409,
#   'id_str': '1287952280218513409',
#   'full_text': 'RT @Absolutalbert: VP isn’t invited to SONA? \n\nDesignated Survivor.',
#   'truncated': False,
#   'display_text_range': [0, 67],
#   'entities': {'hashtags': [],
#    'symbols': [],
#    'user_mentions': [{'screen_name': 'Absolutalbert',
#      'name': 'UNHAPPY PRIDE ✊🏼✊🏼✊🏼',
#      'id': 26975047,
#      'id_str': '26975047',
#      'indices': [3, 17]}],
#    'urls': []},
#   'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#   'source': '<a href="http://twitter.com/download/android" rel="nofollow">Twitter for Android</a>',
#   'in_reply_to_status_id': None,
#   'in_reply_to_status_id_str': None,
#   'in_reply_to_user_id': None,
#   'in_reply_to_user_id_str': None,
#   'in_reply_to_screen_name': None,
#   'user': {'id': 606252977,
#    'id_str': '606252977',
#    'name': 'BIANXXI凡',
#    'screen_name': '_ninjawu',
#    'location': '',
#    'description': 'I overthink a lot and am very awkward',
#    'url': None,
#    'entities': {'description': {'urls': []}},
#    'protected': False,
#    'followers_count': 516,
#    'friends_count': 809,
#    'listed_count': 7,
#    'created_at': 'Tue Jun 12 11:47:58 +0000 2012',
#    'favourites_count': 7773,
#    'utc_offset': None,
#    'time_zone': None,
#    'geo_enabled': True,
#    'verified': False,
#    'statuses_count': 41034,
#    'lang': None,
#    'contributors_enabled': False,
#    'is_translator': False,
#    'is_translation_enabled': False,
#    'profile_background_color': 'C0DEED',
#    'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme14/bg.gif',
#    'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme14/bg.gif',
#    'profile_background_tile': True,
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/1282018991020498944/BNoord1__normal.jpg',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1282018991020498944/BNoord1__normal.jpg',
#    'profile_banner_url': 'https://pbs.twimg.com/profile_banners/606252977/1511244385',
#    'profile_link_color': '1D00B0',
#    'profile_sidebar_border_color': 'FFFFFF',
#    'profile_sidebar_fill_color': 'EFEFEF',
#    'profile_text_color': '333333',
#    'profile_use_background_image': True,
#    'has_extended_profile': False,
#    'default_profile': False,
#    'default_profile_image': False,
#    'following': False,
#    'follow_request_sent': False,
#    'notifications': False,
#    'translator_type': 'none'},
#   'geo': None,
#   'coordinates': None,
#   'place': None,
#   'contributors': None,
#   'retweeted_status': {'created_at': 'Mon Jul 27 04:15:28 +0000 2020',
#    'id': 1287602480046419968,
#    'id_str': '1287602480046419968',
#    'full_text': 'VP isn’t invited to SONA? \n\nDesignated Survivor.',
#    'truncated': False,
#    'display_text_range': [0, 48],
#    'entities': {'hashtags': [],
#     'symbols': [],
#     'user_mentions': [],
#     'urls': []},
#    'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#    'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'in_reply_to_screen_name': None,
#    'user': {'id': 26975047,
#     'id_str': '26975047',
#     'name': 'UNHAPPY PRIDE ✊🏼✊🏼✊🏼',
#     'screen_name': 'Absolutalbert',
#     'location': '',
#     'description': 'ᴍᴀʏ ᴏʀ ᴍᴀʏ ɴᴏᴛ ʙᴇ ᴀ ʟᴏɴɢ ᴄᴏɴ',
#     'url': 'https://t.co/1JG6p0VW0q',
#     'entities': {'url': {'urls': [{'url': 'https://t.co/1JG6p0VW0q',
#         'expanded_url': 'http://onlyfans.com/absolutalbert',
#         'display_url': 'onlyfans.com/absolutalbert',
#         'indices': [0, 23]}]},
#      'description': {'urls': []}},
#     'protected': False,
#     'followers_count': 4947,
#     'friends_count': 577,
#     'listed_count': 9,
#     'created_at': 'Fri Mar 27 09:10:25 +0000 2009',
#     'favourites_count': 58233,
#     'utc_offset': None,
#     'time_zone': None,
#     'geo_enabled': False,
#     'verified': False,
#     'statuses_count': 84229,
#     'lang': None,
#     'contributors_enabled': False,
#     'is_translator': False,
#     'is_translation_enabled': False,
#     'profile_background_color': 'FFFFFF',
#     'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#     'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#     'profile_background_tile': False,
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/1277603840431357952/v0MUBPZG_normal.jpg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1277603840431357952/v0MUBPZG_normal.jpg',
#     'profile_banner_url': 'https://pbs.twimg.com/profile_banners/26975047/1593772992',
#     'profile_link_color': '0047AB',
#     'profile_sidebar_border_color': 'FFFFFF',
#     'profile_sidebar_fill_color': 'FFFFFF',
#     'profile_text_color': '2C2C2C',
#     'profile_use_background_image': False,
#     'has_extended_profile': False,
#     'default_profile': False,
#     'default_profile_image': False,
#     'following': False,
#     'follow_request_sent': False,
#     'notifications': False,
#     'translator_type': 'none'},
#    'geo': None,
#    'coordinates': None,
#    'place': None,
#    'contributors': None,
#    'is_quote_status': False,
#    'retweet_count': 2755,
#    'favorite_count': 33837,
#    'favorited': False,
#    'retweeted': False,
#    'lang': 'en'},
#   'is_quote_status': False,
#   'retweet_count': 2755,
#   'favorite_count': 0,
#   'favorited': False,
#   'retweeted': False,
#   'lang': 'en'},
#  {'created_at': 'Tue Jul 28 03:25:24 +0000 2020',
#   'id': 1287952267652587521,
#   'id_str': '1287952267652587521',
#   'full_text': 'RT @cnnphilippines: THREAD: Duterte pushed for the reimposition of capital punishment, specifying the method of lethal injection, for heino…',
#   'truncated': False,
#   'display_text_range': [0, 140],
#   'entities': {'hashtags': [],
#    'symbols': [],
#    'user_mentions': [{'screen_name': 'cnnphilippines',
#      'name': 'CNN Philippines',
#      'id': 2811559122,
#      'id_str': '2811559122',
#      'indices': [3, 18]}],
#    'urls': []},
#   'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#   'source': '<a href="https://mobile.twitter.com" rel="nofollow">Twitter Web App</a>',
#   'in_reply_to_status_id': None,
#   'in_reply_to_status_id_str': None,
#   'in_reply_to_user_id': None,
#   'in_reply_to_user_id_str': None,
#   'in_reply_to_screen_name': None,
#   'user': {'id': 166303791,
#    'id_str': '166303791',
#    'name': 'Bogotá News',
#    'screen_name': 'surgaitana',
#    'location': 'Bogotá',
#    'description': "Cycling fan. Learning and practicing English. Enjoying music! Peace's supporter. Against Bullfighting, corruption and inequality!",
#    'url': None,
#    'entities': {'description': {'urls': []}},
#    'protected': False,
#    'followers_count': 1522,
#    'friends_count': 1913,
#    'listed_count': 49,
#    'created_at': 'Tue Jul 13 20:44:36 +0000 2010',
#    'favourites_count': 367,
#    'utc_offset': None,
#    'time_zone': None,
#    'geo_enabled': False,
#    'verified': False,
#    'statuses_count': 41150,
#    'lang': None,
#    'contributors_enabled': False,
#    'is_translator': False,
#    'is_translation_enabled': False,
#    'profile_background_color': '131516',
#    'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme14/bg.gif',
#    'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme14/bg.gif',
#    'profile_background_tile': True,
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/1200076723515211778/9ohH4inE_normal.jpg',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1200076723515211778/9ohH4inE_normal.jpg',
#    'profile_banner_url': 'https://pbs.twimg.com/profile_banners/166303791/1590509941',
#    'profile_link_color': '009999',
#    'profile_sidebar_border_color': 'FFFFFF',
#    'profile_sidebar_fill_color': 'EFEFEF',
#    'profile_text_color': '333333',
#    'profile_use_background_image': True,
#    'has_extended_profile': False,
#    'default_profile': False,
#    'default_profile_image': False,
#    'following': False,
#    'follow_request_sent': False,
#    'notifications': False,
#    'translator_type': 'none'},
#   'geo': None,
#   'coordinates': None,
#   'place': None,
#   'contributors': None,
#   'retweeted_status': {'created_at': 'Tue Jul 28 02:22:40 +0000 2020',
#    'id': 1287936482129227776,
#    'id_str': '1287936482129227776',
#    'full_text': 'THREAD: Duterte pushed for the reimposition of capital punishment, specifying the method of lethal injection, for heinous crimes related to illegal drugs in his #SONA2020.\n\nClick this thread for reactions from lawmakers, officials. https://t.co/ti8HRwL4VH',
#    'truncated': False,
#    'display_text_range': [0, 255],
#    'entities': {'hashtags': [{'text': 'SONA2020', 'indices': [161, 170]}],
#     'symbols': [],
#     'user_mentions': [],
#     'urls': [{'url': 'https://t.co/ti8HRwL4VH',
#       'expanded_url': 'https://bit.ly/3hL3aUL',
#       'display_url': 'bit.ly/3hL3aUL',
#       'indices': [232, 255]}]},
#    'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#    'source': '<a href="https://about.twitter.com/products/tweetdeck" rel="nofollow">TweetDeck</a>',
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'in_reply_to_screen_name': None,
#    'user': {'id': 2811559122,
#     'id_str': '2811559122',
#     'name': 'CNN Philippines',
#     'screen_name': 'cnnphilippines',
#     'location': 'Philippines',
#     'description': 'News you can trust • Free TV channel 9',
#     'url': 'https://t.co/mNT2ehDCaF',
#     'entities': {'url': {'urls': [{'url': 'https://t.co/mNT2ehDCaF',
#         'expanded_url': 'http://www.cnnphilippines.com',
#         'display_url': 'cnnphilippines.com',
#         'indices': [0, 23]}]},
#      'description': {'urls': []}},
#     'protected': False,
#     'followers_count': 1020893,
#     'friends_count': 386,
#     'listed_count': 2148,
#     'created_at': 'Mon Sep 15 16:27:24 +0000 2014',
#     'favourites_count': 48,
#     'utc_offset': None,
#     'time_zone': None,
#     'geo_enabled': True,
#     'verified': True,
#     'statuses_count': 452343,
#     'lang': None,
#     'contributors_enabled': False,
#     'is_translator': False,
#     'is_translation_enabled': False,
#     'profile_background_color': 'FFFFFF',
#     'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#     'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#     'profile_background_tile': False,
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/947598867985457152/lOzb5ud9_normal.jpg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/947598867985457152/lOzb5ud9_normal.jpg',
#     'profile_banner_url': 'https://pbs.twimg.com/profile_banners/2811559122/1584513054',
#     'profile_link_color': 'DD2E44',
#     'profile_sidebar_border_color': 'C0DEED',
#     'profile_sidebar_fill_color': 'DDEEF6',
#     'profile_text_color': '333333',
#     'profile_use_background_image': False,
#     'has_extended_profile': False,
#     'default_profile': False,
#     'default_profile_image': False,
#     'following': False,
#     'follow_request_sent': False,
#     'notifications': False,
#     'translator_type': 'regular'},
#    'geo': None,
#    'coordinates': None,
#    'place': None,
#    'contributors': None,
#    'is_quote_status': False,
#    'retweet_count': 6,
#    'favorite_count': 11,
#    'favorited': False,
#    'retweeted': False,
#    'possibly_sensitive': False,
#    'lang': 'en'},
#   'is_quote_status': False,
#   'retweet_count': 6,
#   'favorite_count': 0,
#   'favorited': False,
#   'retweeted': False,
#   'lang': 'en'},
#  {'created_at': 'Tue Jul 28 03:25:22 +0000 2020',
#   'id': 1287952260434022401,
#   'id_str': '1287952260434022401',
#   'full_text': 'RT @quarkhenares: WHY. WHY DO THEY EVEN GET FILMMAKERS TO SHOOT THE FUCKING SONA',
#   'truncated': False,
#   'display_text_range': [0, 80],
#   'entities': {'hashtags': [],
#    'symbols': [],
#    'user_mentions': [{'screen_name': 'quarkhenares',
#      'name': 'Quark Henares',
#      'id': 49212471,
#      'id_str': '49212471',
#      'indices': [3, 16]}],
#    'urls': []},
#   'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#   'source': '<a href="http://twitter.com/download/android" rel="nofollow">Twitter for Android</a>',
#   'in_reply_to_status_id': None,
#   'in_reply_to_status_id_str': None,
#   'in_reply_to_user_id': None,
#   'in_reply_to_user_id_str': None,
#   'in_reply_to_screen_name': None,
#   'user': {'id': 2417049620,
#    'id_str': '2417049620',
#    'name': 'christy Beduyas',
#    'screen_name': 'Christybeduyas8',
#    'location': 'cavite,ph',
#    'description': '🎗♥️🐕',
#    'url': None,
#    'entities': {'description': {'urls': []}},
#    'protected': False,
#    'followers_count': 195,
#    'friends_count': 118,
#    'listed_count': 0,
#    'created_at': 'Sat Mar 29 06:29:05 +0000 2014',
#    'favourites_count': 10210,
#    'utc_offset': None,
#    'time_zone': None,
#    'geo_enabled': False,
#    'verified': False,
#    'statuses_count': 38447,
#    'lang': None,
#    'contributors_enabled': False,
#    'is_translator': False,
#    'is_translation_enabled': False,
#    'profile_background_color': 'C0DEED',
#    'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#    'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#    'profile_background_tile': False,
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/1255918840317239296/IqUjO1gz_normal.jpg',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1255918840317239296/IqUjO1gz_normal.jpg',
#    'profile_banner_url': 'https://pbs.twimg.com/profile_banners/2417049620/1493697341',
#    'profile_link_color': '1DA1F2',
#    'profile_sidebar_border_color': 'C0DEED',
#    'profile_sidebar_fill_color': 'DDEEF6',
#    'profile_text_color': '333333',
#    'profile_use_background_image': True,
#    'has_extended_profile': True,
#    'default_profile': True,
#    'default_profile_image': False,
#    'following': False,
#    'follow_request_sent': False,
#    'notifications': False,
#    'translator_type': 'none'},
#   'geo': None,
#   'coordinates': None,
#   'place': None,
#   'contributors': None,
#   'retweeted_status': {'created_at': 'Mon Jul 27 11:02:16 +0000 2020',
#    'id': 1287704856367525889,
#    'id_str': '1287704856367525889',
#    'full_text': 'WHY. WHY DO THEY EVEN GET FILMMAKERS TO SHOOT THE FUCKING SONA',
#    'truncated': False,
#    'display_text_range': [0, 62],
#    'entities': {'hashtags': [],
#     'symbols': [],
#     'user_mentions': [],
#     'urls': []},
#    'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#    'source': '<a href="https://about.twitter.com/products/tweetdeck" rel="nofollow">TweetDeck</a>',
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'in_reply_to_screen_name': None,
#    'user': {'id': 49212471,
#     'id_str': '49212471',
#     'name': 'Quark Henares',
#     'screen_name': 'quarkhenares',
#     'location': 'Manila, Philippines',
#     'description': 'makes films, some of them porn. corrupts children in various schools. writes garbage for publications. tries to sing in rock bands. not gay. no, really.',
#     'url': 'https://t.co/OCXP8xpUOu',
#     'entities': {'url': {'urls': [{'url': 'https://t.co/OCXP8xpUOu',
#         'expanded_url': 'http://giff.ph/watch',
#         'display_url': 'giff.ph/watch',
#         'indices': [0, 23]}]},
#      'description': {'urls': []}},
#     'protected': False,
#     'followers_count': 57673,
#     'friends_count': 380,
#     'listed_count': 332,
#     'created_at': 'Sun Jun 21 03:08:07 +0000 2009',
#     'favourites_count': 2264,
#     'utc_offset': None,
#     'time_zone': None,
#     'geo_enabled': True,
#     'verified': True,
#     'statuses_count': 14870,
#     'lang': None,
#     'contributors_enabled': False,
#     'is_translator': False,
#     'is_translation_enabled': False,
#     'profile_background_color': 'C0DEED',
#     'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#     'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#     'profile_background_tile': True,
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/1155562774/quarkloser_for_twitter_normal.jpg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1155562774/quarkloser_for_twitter_normal.jpg',
#     'profile_banner_url': 'https://pbs.twimg.com/profile_banners/49212471/1407086680',
#     'profile_link_color': '00090F',
#     'profile_sidebar_border_color': 'FFFFFF',
#     'profile_sidebar_fill_color': 'DDEEF6',
#     'profile_text_color': '333333',
#     'profile_use_background_image': True,
#     'has_extended_profile': True,
#     'default_profile': False,
#     'default_profile_image': False,
#     'following': False,
#     'follow_request_sent': False,
#     'notifications': False,
#     'translator_type': 'none'},
#    'geo': None,
#    'coordinates': None,
#    'place': None,
#    'contributors': None,
#    'is_quote_status': False,
# ...
#     'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme9/bg.gif',
#     'profile_background_tile': True,
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/1287234991164776450/iHZcj6el_normal.jpg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1287234991164776450/iHZcj6el_normal.jpg',
#     'profile_banner_url': 'https://pbs.twimg.com/profile_banners/37650624/1559792476',
#     'profile_link_color': '2FC2EF',
#     'profile_sidebar_border_color': '000000',
#     'profile_sidebar_fill_color': '252429',
#     'profile_text_color': '666666',
#     'profile_use_background_image': True,
#     'has_extended_profile': False,
#     'default_profile': False,
#     'default_profile_image': False,
#     'following': False,
#     'follow_request_sent': False,
#     'notifications': False,
#     'translator_type': 'none'},
#    'geo': None,
#    'coordinates': None,
#    'place': {'id': '01bb53b81ba40196',
#     'url': 'https://api.twitter.com/1.1/geo/id/01bb53b81ba40196.json',
#     'place_type': 'city',
#     'name': 'Manila City',
#     'full_name': 'Manila City, National Capital Region',
#     'country_code': 'PH',
#     'country': 'Republic of the Philippines',
#     'contained_within': [],
#     'bounding_box': {'type': 'Polygon',
#      'coordinates': [[[120.9416422, 14.5438774],
#        [121.0263307, 14.5438774],
#        [121.0263307, 14.6390361],
#        [120.9416422, 14.6390361]]]},
#     'attributes': {}},
#    'contributors': None,
#    'is_quote_status': False,
#    'retweet_count': 516,
#    'favorite_count': 4335,
#    'favorited': False,
#    'retweeted': False,
#    'possibly_sensitive': False,
#    'lang': 'en'},
#   'retweet_count': 0,
#   'favorite_count': 2,
#   'favorited': False,
#   'retweeted': False,
#   'possibly_sensitive': False,
#   'lang': 'en'},
#  {'created_at': 'Tue Jul 28 03:22:04 +0000 2020',
#   'id': 1287951430947500032,
#   'id_str': '1287951430947500032',
#   'full_text': 'RT @itsyaboiraff: Joseph Morong listening while typing the minutes of SONA 2020. https://t.co/NQ0ZQWKJ2d',
#   'truncated': False,
#   'display_text_range': [0, 104],
#   'entities': {'hashtags': [],
#    'symbols': [],
#    'user_mentions': [{'screen_name': 'itsyaboiraff',
#      'name': 'Raf',
#      'id': 1165548942714494977,
#      'id_str': '1165548942714494977',
#      'indices': [3, 16]}],
#    'urls': [],
#    'media': [{'id': 1276143903687630859,
#      'id_str': '1276143903687630859',
#      'indices': [81, 104],
#      'media_url': 'http://pbs.twimg.com/ext_tw_video_thumb/1276143903687630859/pu/img/GT8mdJoQ2-xeBpdG.jpg',
#      'media_url_https': 'https://pbs.twimg.com/ext_tw_video_thumb/1276143903687630859/pu/img/GT8mdJoQ2-xeBpdG.jpg',
#      'url': 'https://t.co/NQ0ZQWKJ2d',
#      'display_url': 'pic.twitter.com/NQ0ZQWKJ2d',
#      'expanded_url': 'https://twitter.com/MissMarisRacal/status/1276143948847886338/video/1',
#      'type': 'photo',
#      'sizes': {'thumb': {'w': 150, 'h': 150, 'resize': 'crop'},
#       'small': {'w': 383, 'h': 680, 'resize': 'fit'},
#       'large': {'w': 720, 'h': 1280, 'resize': 'fit'},
#       'medium': {'w': 675, 'h': 1200, 'resize': 'fit'}},
#      'source_status_id': 1276143948847886338,
#      'source_status_id_str': '1276143948847886338',
#      'source_user_id': 628808642,
#      'source_user_id_str': '628808642'}]},
#   'extended_entities': {'media': [{'id': 1276143903687630859,
#      'id_str': '1276143903687630859',
#      'indices': [81, 104],
#      'media_url': 'http://pbs.twimg.com/ext_tw_video_thumb/1276143903687630859/pu/img/GT8mdJoQ2-xeBpdG.jpg',
#      'media_url_https': 'https://pbs.twimg.com/ext_tw_video_thumb/1276143903687630859/pu/img/GT8mdJoQ2-xeBpdG.jpg',
#      'url': 'https://t.co/NQ0ZQWKJ2d',
#      'display_url': 'pic.twitter.com/NQ0ZQWKJ2d',
#      'expanded_url': 'https://twitter.com/MissMarisRacal/status/1276143948847886338/video/1',
#      'type': 'video',
#      'sizes': {'thumb': {'w': 150, 'h': 150, 'resize': 'crop'},
#       'small': {'w': 383, 'h': 680, 'resize': 'fit'},
#       'large': {'w': 720, 'h': 1280, 'resize': 'fit'},
#       'medium': {'w': 675, 'h': 1200, 'resize': 'fit'}},
#      'source_status_id': 1276143948847886338,
#      'source_status_id_str': '1276143948847886338',
#      'source_user_id': 628808642,
#      'source_user_id_str': '628808642',
#      'video_info': {'aspect_ratio': [9, 16],
#       'duration_millis': 6795,
#       'variants': [{'bitrate': 2176000,
#         'content_type': 'video/mp4',
#         'url': 'https://video.twimg.com/ext_tw_video/1276143903687630859/pu/vid/720x1280/xj2cLLXZWzJydqyG.mp4?tag=10'},
#        {'bitrate': 832000,
#         'content_type': 'video/mp4',
#         'url': 'https://video.twimg.com/ext_tw_video/1276143903687630859/pu/vid/360x640/TmB-6iMaA7Z8aTfH.mp4?tag=10'},
#        {'bitrate': 632000,
#         'content_type': 'video/mp4',
#         'url': 'https://video.twimg.com/ext_tw_video/1276143903687630859/pu/vid/320x568/Ml5jhE2AqBu4ZiIS.mp4?tag=10'},
#        {'content_type': 'application/x-mpegURL',
#         'url': 'https://video.twimg.com/ext_tw_video/1276143903687630859/pu/pl/MqpQeq7gRNGBNOV9.m3u8?tag=10'}]},
#      'additional_media_info': {'monetizable': False}}]},
#   'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#   'source': '<a href="http://twitter.com/download/android" rel="nofollow">Twitter for Android</a>',
#   'in_reply_to_status_id': None,
#   'in_reply_to_status_id_str': None,
#   'in_reply_to_user_id': None,
#   'in_reply_to_user_id_str': None,
#   'in_reply_to_screen_name': None,
#   'user': {'id': 909067806162817025,
#    'id_str': '909067806162817025',
#    'name': 'alvin',
#    'screen_name': 'xx__lvn',
#    'location': 'Neverland',
#    'description': 'avait des étoiles dans les yeux ;;; pcy x kji',
#    'url': None,
#    'entities': {'description': {'urls': []}},
#    'protected': False,
#    'followers_count': 422,
#    'friends_count': 407,
#    'listed_count': 2,
#    'created_at': 'Sat Sep 16 14:53:49 +0000 2017',
#    'favourites_count': 30945,
#    'utc_offset': None,
#    'time_zone': None,
#    'geo_enabled': True,
#    'verified': False,
#    'statuses_count': 17577,
#    'lang': None,
#    'contributors_enabled': False,
#    'is_translator': False,
#    'is_translation_enabled': False,
#    'profile_background_color': 'F5F8FA',
#    'profile_background_image_url': None,
#    'profile_background_image_url_https': None,
#    'profile_background_tile': False,
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/1280867135326048260/94WAMec__normal.jpg',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1280867135326048260/94WAMec__normal.jpg',
#    'profile_banner_url': 'https://pbs.twimg.com/profile_banners/909067806162817025/1564731924',
#    'profile_link_color': '1DA1F2',
#    'profile_sidebar_border_color': 'C0DEED',
#    'profile_sidebar_fill_color': 'DDEEF6',
#    'profile_text_color': '333333',
#    'profile_use_background_image': True,
#    'has_extended_profile': True,
#    'default_profile': True,
#    'default_profile_image': False,
#    'following': False,
#    'follow_request_sent': False,
#    'notifications': False,
#    'translator_type': 'none'},
#   'geo': None,
#   'coordinates': None,
#   'place': None,
#   'contributors': None,
#   'retweeted_status': {'created_at': 'Mon Jul 27 10:51:29 +0000 2020',
#    'id': 1287702140798943232,
#    'id_str': '1287702140798943232',
#    'full_text': 'Joseph Morong listening while typing the minutes of SONA 2020. https://t.co/NQ0ZQWKJ2d',
#    'truncated': False,
#    'display_text_range': [0, 86],
#    'entities': {'hashtags': [],
#     'symbols': [],
#     'user_mentions': [],
#     'urls': [],
#     'media': [{'id': 1276143903687630859,
#       'id_str': '1276143903687630859',
#       'indices': [63, 86],
#       'media_url': 'http://pbs.twimg.com/ext_tw_video_thumb/1276143903687630859/pu/img/GT8mdJoQ2-xeBpdG.jpg',
#       'media_url_https': 'https://pbs.twimg.com/ext_tw_video_thumb/1276143903687630859/pu/img/GT8mdJoQ2-xeBpdG.jpg',
#       'url': 'https://t.co/NQ0ZQWKJ2d',
#       'display_url': 'pic.twitter.com/NQ0ZQWKJ2d',
#       'expanded_url': 'https://twitter.com/MissMarisRacal/status/1276143948847886338/video/1',
#       'type': 'photo',
#       'sizes': {'thumb': {'w': 150, 'h': 150, 'resize': 'crop'},
#        'small': {'w': 383, 'h': 680, 'resize': 'fit'},
#        'large': {'w': 720, 'h': 1280, 'resize': 'fit'},
#        'medium': {'w': 675, 'h': 1200, 'resize': 'fit'}},
#       'source_status_id': 1276143948847886338,
#       'source_status_id_str': '1276143948847886338',
#       'source_user_id': 628808642,
#       'source_user_id_str': '628808642'}]},
#    'extended_entities': {'media': [{'id': 1276143903687630859,
#       'id_str': '1276143903687630859',
#       'indices': [63, 86],
#       'media_url': 'http://pbs.twimg.com/ext_tw_video_thumb/1276143903687630859/pu/img/GT8mdJoQ2-xeBpdG.jpg',
#       'media_url_https': 'https://pbs.twimg.com/ext_tw_video_thumb/1276143903687630859/pu/img/GT8mdJoQ2-xeBpdG.jpg',
#       'url': 'https://t.co/NQ0ZQWKJ2d',
#       'display_url': 'pic.twitter.com/NQ0ZQWKJ2d',
#       'expanded_url': 'https://twitter.com/MissMarisRacal/status/1276143948847886338/video/1',
#       'type': 'video',
#       'sizes': {'thumb': {'w': 150, 'h': 150, 'resize': 'crop'},
#        'small': {'w': 383, 'h': 680, 'resize': 'fit'},
#        'large': {'w': 720, 'h': 1280, 'resize': 'fit'},
#        'medium': {'w': 675, 'h': 1200, 'resize': 'fit'}},
#       'source_status_id': 1276143948847886338,
#       'source_status_id_str': '1276143948847886338',
#       'source_user_id': 628808642,
#       'source_user_id_str': '628808642',
#       'video_info': {'aspect_ratio': [9, 16],
#        'duration_millis': 6795,
#        'variants': [{'bitrate': 2176000,
#          'content_type': 'video/mp4',
#          'url': 'https://video.twimg.com/ext_tw_video/1276143903687630859/pu/vid/720x1280/xj2cLLXZWzJydqyG.mp4?tag=10'},
#         {'bitrate': 832000,
#          'content_type': 'video/mp4',
#          'url': 'https://video.twimg.com/ext_tw_video/1276143903687630859/pu/vid/360x640/TmB-6iMaA7Z8aTfH.mp4?tag=10'},
#         {'bitrate': 632000,
#          'content_type': 'video/mp4',
#          'url': 'https://video.twimg.com/ext_tw_video/1276143903687630859/pu/vid/320x568/Ml5jhE2AqBu4ZiIS.mp4?tag=10'},
#         {'content_type': 'application/x-mpegURL',
#          'url': 'https://video.twimg.com/ext_tw_video/1276143903687630859/pu/pl/MqpQeq7gRNGBNOV9.m3u8?tag=10'}]},
#       'additional_media_info': {'monetizable': False}}]},
#    'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#    'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'in_reply_to_screen_name': None,
#    'user': {'id': 1165548942714494977,
#     'id_str': '1165548942714494977',
#     'name': 'Raf',
#     'screen_name': 'itsyaboiraff',
#     'location': 'Caloocan City, National Capital Region',
#     'description': '22 | INFJ-T | Tamaraw | Pokéfan',
#     'url': None,
#     'entities': {'description': {'urls': []}},
#     'protected': False,
#     'followers_count': 59,
#     'friends_count': 65,
#     'listed_count': 0,
#     'created_at': 'Sun Aug 25 08:58:30 +0000 2019',
#     'favourites_count': 352,
#     'utc_offset': None,
#     'time_zone': None,
#     'geo_enabled': True,
#     'verified': False,
#     'statuses_count': 35,
#     'lang': None,
#     'contributors_enabled': False,
#     'is_translator': False,
#     'is_translation_enabled': False,
#     'profile_background_color': 'F5F8FA',
#     'profile_background_image_url': None,
#     'profile_background_image_url_https': None,
#     'profile_background_tile': False,
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/1283021959605784576/Gh7An8UV_normal.jpg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1283021959605784576/Gh7An8UV_normal.jpg',
#     'profile_banner_url': 'https://pbs.twimg.com/profile_banners/1165548942714494977/1578271455',
#     'profile_link_color': '1DA1F2',
#     'profile_sidebar_border_color': 'C0DEED',
#     'profile_sidebar_fill_color': 'DDEEF6',
#     'profile_text_color': '333333',
#     'profile_use_background_image': True,
#     'has_extended_profile': True,
#     'default_profile': True,
#     'default_profile_image': False,
#     'following': False,
#     'follow_request_sent': False,
#     'notifications': False,
#     'translator_type': 'none'},
#    'geo': None,
#    'coordinates': None,
#    'place': None,
#    'contributors': None,
#    'is_quote_status': False,
#    'retweet_count': 832,
#    'favorite_count': 7299,
#    'favorited': False,
#    'retweeted': False,
#    'possibly_sensitive': False,
#    'lang': 'en'},
#   'is_quote_status': False,
#   'retweet_count': 832,
#   'favorite_count': 0,
#   'favorited': False,
#   'retweeted': False,
#   'possibly_sensitive': False,
#   'lang': 'en'},
#  {'created_at': 'Tue Jul 28 03:22:04 +0000 2020',
#   'id': 1287951430863577094,
#   'id_str': '1287951430863577094',
#   'full_text': 'Duterte asks Congress to pass 21 bills during the remainder of his presidency. Only 5 were specifically designed to respond to the COVID-19 crisis, reports @maracepeda \n\nhttps://t.co/6F8GGFl7GU',
#   'truncated': False,
#   'display_text_range': [0, 193],
#   'entities': {'hashtags': [],
#    'symbols': [],
#    'user_mentions': [{'screen_name': 'maracepeda',
#      'name': 'Mara Cepeda',
#      'id': 51329146,
#      'id_str': '51329146',
#      'indices': [156, 167]}],
#    'urls': [{'url': 'https://t.co/6F8GGFl7GU',
#      'expanded_url': 'https://rappler.com/newsbreak/iq/list-priority-bills-duterte-sona-2020',
#      'display_url': 'rappler.com/newsbreak/iq/l…',
#      'indices': [170, 193]}]},
#   'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#   'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#   'in_reply_to_status_id': None,
#   'in_reply_to_status_id_str': None,
#   'in_reply_to_user_id': None,
#   'in_reply_to_user_id_str': None,
#   'in_reply_to_screen_name': None,
#   'user': {'id': 3343352686,
#    'id_str': '3343352686',
#    'name': 'Sofia Tomacruz',
#    'screen_name': 'sofiatomacruz',
#    'location': 'Philippines',
#    'description': 'Multimedia reporter, @rapplerdotcom. Covers foreign affairs, elections, & overseas Filipinos | Tips or story ideas? Email them to sofia.tomacruz@rappler.com',
#    'url': 'https://t.co/vCJius5lPx',
#    'entities': {'url': {'urls': [{'url': 'https://t.co/vCJius5lPx',
#        'expanded_url': 'http://rappler.com',
#        'display_url': 'rappler.com',
#        'indices': [0, 23]}]},
#     'description': {'urls': []}},
#    'protected': False,
#    'followers_count': 1782,
#    'friends_count': 1515,
#    'listed_count': 22,
#    'created_at': 'Tue Jun 23 23:22:01 +0000 2015',
#    'favourites_count': 2502,
#    'utc_offset': None,
#    'time_zone': None,
#    'geo_enabled': False,
#    'verified': True,
#    'statuses_count': 5758,
#    'lang': None,
#    'contributors_enabled': False,
#    'is_translator': False,
#    'is_translation_enabled': False,
#    'profile_background_color': 'C0DEED',
#    'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#    'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#    'profile_background_tile': False,
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/1268558115114369024/sDz6C8LD_normal.jpg',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1268558115114369024/sDz6C8LD_normal.jpg',
#    'profile_banner_url': 'https://pbs.twimg.com/profile_banners/3343352686/1535382393',
#    'profile_link_color': '1DA1F2',
#    'profile_sidebar_border_color': 'C0DEED',
#    'profile_sidebar_fill_color': 'DDEEF6',
#    'profile_text_color': '333333',
#    'profile_use_background_image': True,
#    'has_extended_profile': True,
#    'default_profile': True,
#    'default_profile_image': False,
#    'following': False,
#    'follow_request_sent': False,
#    'notifications': False,
#    'translator_type': 'none'},
#   'geo': None,
#   'coordinates': None,
#   'place': None,
#   'contributors': None,
#   'is_quote_status': False,
#   'retweet_count': 0,
#   'favorite_count': 0,
#   'favorited': False,
#   'retweeted': False,
#   'possibly_sensitive': False,
#   'lang': 'en'}]

# %% [markdown]
# You won't really need to understand everything in the tweet object, but in case you want to know more, here is the documentation from the [Twitter Developer Website](https://developer.twitter.com/en/docs/tweets/data-dictionary/overview/tweet-object).

# %% [markdown]
# #### 2.1.1.
#
# Print out the length of the number of tweets. Expected output is shown below.

# %%
# write your code here
print(len(tweets))
# Out:
# 100

# %% [markdown]
# #### 2.1.2.
#
# Define a list variable named `tweet_texts` of tweet texts contained in `tweets`  (which is the value of the `full_text` key).
#
# Do a printout (using **script mode**) of the contents of `tweet_texts`. You will have to loop through each element of the list.
#
# Sample output is provided below.

# %%
# write code here.
tweet_texts = [(i["full_text"]) for i in tweets]


# Dump tweet_texts (script mode)
print(tweet_texts)
# Out:
# ['RT @watchmejayjay: Ay di ka nakanood ng SONA? Wag ka mag-alala, ito yung summary ng mga plano ni tatay laban sa COVID 19: A thread', 'RT @TOWER_Namba: 【#ジェジュン】\n\n\\カバーアルバムを引っさげたツアー映像🎥/\n\nツアー映像『J-JUN LIVE 2019～Love Covers～』本日入荷しました🙌\n2日間のみのプレミアムライヴを映像とCDでお楽しみいただける豪華盤!!!\n\nCDがあれば…', '@kapilkolotya @kharaa_sona_ Bhai jo le liya hai mene 3saal pehle usko me Boycott kr duga. But\n\nMujy Made in india IPHONE dedo.', 'RT @TOWER_Namba: 【#ジェジュン】\n\n\\ジェジュンの優しく、深い歌声がしみわたる..../\n\nカバーアルバム『Love Covers Ⅱ』本日入荷しました🙌\n原曲の良さをひきたてるだけでなく、ジェジュンらしさも全開のアルバムです♪\n\n🎁タワレコ特典はアナザージャ…', 'RT @JaDineTrash: Her own time. \nHer own thoughts. \nHer own style. \n\nThank you, Nadine. The battles you fight have always been for a bigger…', 'RT @Absolutalbert: VP isn’t invited to SONA? \n\nDesignated Survivor.', 'RT @cnnphilippines: THREAD: Duterte pushed for the reimposition of capital punishment, specifying the method of lethal injection, for heino…', 'RT @quarkhenares: WHY. WHY DO THEY EVEN GET FILMMAKERS TO SHOOT THE FUCKING SONA', 'RT @Hashtag_nikko13: Di ko nakita yung sona😢😢\nHayaan ko na nga di rin naman nila tayo nakikita', "I hope that we can get some or the same treatment of clarity, purpose &amp; the fastness to support the passage of the Bayanihan [to Recover as One Act], which will supplement funds for recovery &amp; response against the impact of the #COVID-19 pandemic.\n\n-President #Duterte's 5th #SONA", 'RT @gmanews: Philippine neighbors standing up to China without war, Carpio tells Duterte after SONA https://t.co/nieAExKbCu', '@ReaperSZN__ Stupid no-maskers ruining the fun for everyone, online &amp; off 😭😭', 'RT @iamkarendavila: Okay, clearly Senator Franklin Drilon is in the President’s consciousness. Mentioning him again in the SONA. Calls him…', 'OUR MARAWI:  Fake News: Walang Human rights Violation sa Martial Law ni Duterte sabi nya sa kanyang SONA https://t.co/YDt5a7f6KI \n\n#ThisIsOurMindanao', "RT @Joseph_Morong: Tadah! Highlights of Pres. Duterte's 5th SONA @gmanews https://t.co/bc4vfGyRpq", '@marvsmodel Maliban sa war sila ni vice, nasa SONA pala siya. 😁', '@serahphymn Totally a 5 🥺 If my sona met him they would totally vibe', '@Fahmiraza1Raza @ajmaljami Bhai kachra dumping ka name sona  hy kbhi??? Kachra paida hona ha gvt na osko dispose krna ha jab ni hoga ya hoga log kahan dumpkry batao', 'RT @HMV_Kawasaki: 【#ジェジュン】大ヒットしたカバーアルバムの第2弾「Love Covers II」入荷しました✨CDの2形態には先着ご購入特典で「アナザージャケット（HMV絵柄）」をお付けしています🌹プレミアムライブを収録した映像作品「J-JUN LIVE…', 'RT @rapplerdotcom: "The message seems clear: Smart and Globe go the way of ABS-CBN if they cannot clear the creative legal hurdles that wil…', 'RT @Absolutalbert: VP isn’t invited to SONA? \n\nDesignated Survivor.', 'Evanu thala kaga varala elan fc page ku tha fans ya erkanga yaru tag sona enada kiruiu ko🔥gala\n#valimai #ThalaAjith #Ajithkumar https://t.co/hQ14YGO6lU', 'LIST: 21 priority bills of Duterte in SONA 2020 | by @maracepeda \n\nhttps://t.co/CSiWT3lZ3O', '@ABSCBNNews @_katrinadomingo did we watch the same version of SONA?? Iba ata napanood ni Imee', 'RT @ItsACsLife: the fact that this year’s SONA won’t reach the whole nation because the only station that can reach everyone nationwide was…', 'RT @HanssensAnthony: Here is my sona ^^ https://t.co/x0aw68yuY5', 'DDS: "Mag SONA kayo ng inyo"\n\nLIKE ANO NA NAMAN YAN? AMPOTA HAHAHA', "May I again reiterate my thanks to you, the men and women of Congress, for the effort you invested into passing that law.\n\n-President Rodrigo Roa #Duterte's 5th #SONA", 'Quédate con la persona que no te deje ir a dormir sin antes decirte "decansa,soña bonito y recuerda que te quiero mucho".', 'RT @gmanews: LOOK: Pati mga health worker, sumali sa anti-SONA rally kaninang umaga sa UP Diliman. \n\nAyon sa mga dumalo, malala ang mga pro…', "RT @leamaine2019: Hello there, my Queen @mainedcm!\xa0 I'll be attending PRRD's SONA w/ leaders across the globe so I won't be able to tweet f…", 'RT @heroangel17: SONA\nState Of No Accomplishment\n\n🤭✊', 'Difficult step .\nMere liye k ...

# %% [markdown]
# #### 2.1.3.
#
# Remove duplicate tweet text lines and save the resulting (cleaned-up) list in the same variable `tweet_texts`.
#
# Hint: using sets may save you a bit of headache.
#
# Sample output is provided below for your reference.

# %%
# write code here
tweet_texts = set(tweet_texts)

# dump, assuming variable name is tweet_texts
print(tweet_texts)

# note that after "de-duplication" (removing of duplicates), we should only have 90 tweet text lines left.
print(len(tweet_texts))
# Out:
# {'@serahphymn Totally a 5 🥺 If my sona met him they would totally vibe', 'RT @cnnphilippines: THREAD: Duterte pushed for the reimposition of capital punishment, specifying the method of lethal injection, for heino…
', "RT @leamaine2019: Hello there, my Queen @mainedcm!\xa ...
# 90

# %% [markdown]
# ### 2.2.
#
# Here we build our wordcount statistics.
#
# #### 2.2.1.
#
# Let's store our count stats in a dictionary variable named `words_dict`.
#
# For each line, let's remove special characters contained in the following string:
#
# `"&$@[].,'#()-\"!?’_"`
#
# Print the resulting dictionary. Sample output is provided below.

# %%
words_dict = dict()

remove_chars = "&$@[].,'#()-\"!?’_{};"

# Write code below
# use as many lines as needed but within this same cell only.
# -----------------------------------------------------------
for i in remove_chars:
    tweet_texts = str(tweet_texts).replace(i,"")
    tweet_texts = tweet_texts.upper()
    words = tweet_texts.split()

for j in words:
    words_dict[j] = words_dict.get(j,0)+1 

# -----------------------------------------------------------
# Dump dictionary contents here        
print(words_dict)
# Out:
# {'SERAHPHYMN': 1, 'TOTALLY': 2, 'A': 6, '5': 2, '🥺': 1, 'IF': 3, 'MY': 8, 'SONA': 61, 'MET': 1, 'HIM': 3, 'THEY': 4, 'WOULD': 3, 'VIBE': 1, 'RT': 53, 'CNNPHILIPPINES:': 2, 'THREAD:': 1, 'DUTERTE': 8, 'PUSHED': 1, 'FOR': 11, 'THE': 55, 'REIMPOSITION': 1, 'OF': 30, 'CAPITAL': 1, 'PUNISHMENT': 1, 'SPECIFYING': 1, 'METHOD': 1, 'LETHAL': 1, 'INJECTION': 1, 'HEINO…': 1, 'CHAIHARVEST': 1, 'OPEN': 1, 'YOUR': 2, 'PURSE': 1, 'SHOW': 1, 'ME': 3, 'DIFFICULT': 1, 'STEP': 2, '\\NMERE': 1, 'LIYE': 1, 'KAR': 2, 'LEGA': 1, 'ROHITME': 1, 'LUNGA': 1, 'KO': 4, 'PASAND': 1, 'HE': 2, '🙂\\N\\NKAHAANHUMKAHAANTUM': 1, 'RONAKSHI': 1, '\\N': 1, 'KARPIKA': 1, 'KARANVGROVER': 1, 'DIPIKAKAKAR': 1, '\\NTUM': 1, 'JAO': 1, 'GHAR': 1, 'PE': 1, 'MUJHE': 1, 'SIKHA': 1, 'DEGI': 1, '😂😂😂': 1, '\\NMUJHE': 1, 'MAZA': 1, 'AAYA': 1, 'THA': 3, '😂😂': 1, 'HTTPS://TCO/AQRFUUJS0I': 1, 'NEKOSONA': 1, 'HTTPS://TCO/HKJZWDY1X5': 1, 'INQUIRERDOTNET:': 1, 'LOOK:': 2, 'GROUPS': 2, 'FROM': 3, 'DIFFERENT': 1, 'SECTORS': 1, 'GATHER': 1, 'AT': 2, 'UP': 5, 'DILIMAN': 2, 'QUEZON': 1, 'CITY': 1, 'ON': 5, 'MONDAY': 1, 'JULY': 1, '27': 1, 'TO': 34, 'PROTEST': 2, 'HOURS': 1, 'BEFORE': 3, 'F…': 2, 'THIS': 7, 'HEALTH': 2, 'EMERGENCY': 1, 'STRETCHED': 1, 'GOVERNMENTS': 1, 'RESOURCES': 1, 'ITS': 3, 'LIMITS': 1, 'IN': 11, 'RESPONSE': 2, 'OFFICE': 1, 'PRESIDENT': 3, 'WORKED': 1, 'CLOSELY': 1, 'WITH': 8, 'CONGRESS': 3, 'QUICK': 1, 'PASSAGE':
日間のみのプレミアムライヴを映像とCDでお楽しみいただける豪華盤\\N\\NCDがあれば…': 1, 'BENOKCASTILLO:': 1, 'IKUMPARA': 1, 'TESTIMONYA': 1, 'NANAY': 1, 'PLARIDELDLSU:': 1, 'NGAYONG': 2, 'ARAW': 3, 'ISASAGAWA': 1, 'IKALIMANG': 1, 'NAGKAROON': 1, 'MGA': 12, 'PAGBABAGO': 1, 'DAHIL': 1, 'PANDEMYANG': 1, 'IDINULOT': 1, 'SONA2…': 1, 'NILOCKDOWN': 1, 'LOOB': 1, 'SIYAM': 1, 'PARA': 2, 'DISINFECTION': 1, 'NEW': 2, 'EXECUTIVE': 2, 'BUILDING': 1, 'MALACAÑANG': 1, 'KUNG': 2, 'SAAN': 2, 'IDINARAOS': 1, 'PRESS': 3, 'BRIEFINGS': 1, 'PALASYO': 1, 'KABILA': 1, 'NITO': 1, 'TULOY': 1, 'NEB': 1, 'POSTSONA': 2, 'CONFERENCE': 1, 'HTTPS://TCO/FJLTIQIW82': 1, 'ABSCBNNEWS': 1, 'KATRINADOMINGO': 2, 'DID': 1, 'WATCH': 1, 'SAME': 2, 'VERSION': 1, 'IBA': 1, 'ATA': 1, 'NAPANOOD': 1, 'IMEE': 1, 'JOSEPHMORONG:': 1, 'TADAH': 1, 'HIGHLIGHTS': 1, 'GMANEWS': 1, 'HTTPS://TCO/BC4VFGYRPQ': 1, 'GIGIESGUERRA ...

# %% [markdown]
# #### 2.2.2.
#
# Now, we would like to have a list of words and counts sorted by count in descending order.
#
# Define a new list variable named `words_list` containing **tuples**, where each tuple is as follows:
#
# *(word, count)*
#
# Dump the contents of `words_list`(in script mode).
#
# Sample output is provided below.

# %%
# write code here
words_list = [(i, v) for i, v in words_dict.items()] 

# dump word_list here, assuming variable name is words_list
print(words_list)
# Out:
# [('SERAHPHYMN', 1), ('TOTALLY', 2), ('A', 6), ('5', 2), ('🥺', 1), ('IF', 3), ('MY', 8), ('SONA', 61), ('MET', 1), ('HIM', 3), ('THEY', 4), ('WOULD', 3), ('VIBE', 1), ('RT', 53), ('CNNPHILIPPINES:', 2), ('THREAD:', 1), ('DUTERTE', 8), ('PUSHED', 1), ('FOR', 11), ('THE', 55), ('REIMPOSITION', 1), ('OF', 30), ('CAPITAL', 1), ('PUNISHMENT', 1), ('SPECIFYING', 1), ('METHOD', 1), ('LETHAL', 1), ('INJECTION', 1), ('HEINO…', 1), ('CHAIHARVEST', 1), ('OPEN', 1), ('YOUR', 2), ('PURSE', 1), ('SHOW', 1), ('ME', 3), ('DIFFICULT', 1), ('STEP', 2), ('\\NMERE', 1), ('LIYE', 1), ('KAR', 2), ('LEGA', 1), ('ROHITME', 1), ('LUNGA', 1), ('KO', 4), ('PASAND', 1), ('HE', 2), ('🙂\\N\\NKAHAANHUMKAHAANTUM', 1), ('RONAKSHI', 1), ('\\N', 1), ('KARPIKA', 1), ('KARANVGROVER', 1), ('DIPIKAKAKAR', 1), ('\\NTUM', 1), ('JAO', 1), ('GHAR', 1), ('PE', 1), ('MUJHE', 1), ('SIKHA', 1), ('DEGI', 1), ('😂😂😂', 
CORONAVIRUS', 1), ('ANG', 20), ('NAKITA', 2), ('UNA', 1), ('NIYANG', 1), ('BAGO', 1), ('NI', 7), ('PRES', 4), ('DUTERTE\\N\\NMARSO', 1), ('NANG', 1), ('TAMAAN', 1), ('PERO', 2), ('GUMALING', 1), ('DIN', 1), ('SIYA', 2), ('KALAUNAN', 1), ('HTTPS://TCO/YVEOXWQ0GT', 1), ('NAKALIMANG', 1), ('AKO', 2), ('DI', 4), ('KA', 4), ('PA', 5), ('RIN', 4), ('INSURED\\NPRES:', 1), ('DUTERTE\\NSONA', 1), ('2020', 7), ('HTTPS://TCO/LAIUKKFKXJ', 1), ('CHARLISCTEX:', 1), ('READING', 1), ('HIS', 5), ('SCRIPT', 1), ('HTTPS://TCO/Q9EER67BIZ', 1), ('TOWERNAMBA:', 2), ('【ジェジュン】\\N\\N\\\\カバーアルバムを引っさげたツアー映像🎥/\\N\\Nツアー映像『JJUN', 1), ('LIVE', 1), ('2019～LOVE', 1), ('COVERS～』本日入荷しました🙌\\N2日間のみのプレミアムライヴを映像とCDでお楽しみいただける豪華盤\\N\\NCDがあれば…', 1), ('BENOKCASTILLO:', 1), ('IKUMPARA', 1), ('TESTIMONYA', 1), ('NANAY', 1), ('PLARIDELDLSU:', 1), ('NGAYONG', 2), ('ARAW', 3), ('ISASAGAWA', 1), ('IKALIMANG', 1), ('NAGKAROON', 1), ('MGA', 12), ('PAGBABAGO', 1), ('DAHIL', 1), ('PANDEMYANG', 1), ('IDINULOT', 1), ('SONA2…', 1), ('NILOCKDOWN', 1), ('LOOB', 1), ('SIYAM', 1), ('PAR ...

# %% [markdown]
# #### 2.2.3
#
# Sort the list by count (which is the second element of each tuple) in **descending** (or reverse) order.
#
# Dump the contents of the newly-sorted list `words_list`.
#
# Sample output shown below.
#
# Hint: this can be done using `lambda` but you can use a regular function definition. Make sure you go through the mini-tutorial at the start of Problem Set 2.

# %%
# write code here
words_list.sort(key=lambda x: x[1], reverse=True)



# dump contents

print(words_list)
# Out:
# [('SONA', 61), ('THE', 55), ('RT', 53), ('TO', 34), ('SA', 34), ('OF', 30), ('ANG', 20), ('NA', 19), ('NG', 14), ('5TH', 13), ('AND', 13), ('MGA', 12), ('FOR', 11), ('IN', 11), ('DUTERTES', 10), ('WE', 9), ('MY', 8), ('DUTERTE', 8), ('WITH', 8), ('THIS', 7), ('COVID19', 7), ('NI', 7), ('2020', 7), ('THAT', 7), ('A', 6), ('MAY', 6), ('I', 6), ('AMP', 6), ('UP', 5), ('ON', 5), ('PA', 5), ('HIS', 5), ('TAG', 5), ('IS', 5), ('THEY', 4), ('KO', 4), ('RODRIGO', 4), ('ROA', 4), ('YOU', 4), ('FIRST', 4), ('SI', 4), ('PRES', 4), ('DI', 4), ('KA', 4), ('RIN', 4), ('YUNG', 4), ('YA', 4), ('STUDENT', 4), ('WAY', 4), ('IF', 3), ('HIM', 3), ('WOULD', 3), ('ME', 3), ('THA', 3), ('FROM', 3), ('BEFORE', 3), ('ITS', 3), ('PRESIDENT', 3), ('CONGRESS', 3), ('ONE', 3),
('CAPITAL', 1), ('PUNISHMENT', 1), ('SPECIFYING', 1), ('METHOD', 1), ('LETHAL', 1), ('INJECTION', 1), ('HEINO…', 1), ('CHAIHARVEST', 1), ('OPEN', 1), ('PURSE', 1), ('SHOW', 1), ('DIFFICULT', 1), ('\\NMERE', 1), ('LIYE', 1), ('LEGA', 1), ('ROHITME', 1), ('LUNGA', 1), ('PASAND', 1), ('🙂\\N\\NKAHAANHUMKAHAANTUM', 1), ('RONAKSHI', 1), ('\\N', 1), ('KARPIKA', 1), ('KARANVGROVER', 1), ('DIPIKAKAKAR', 1), ('\\NTUM', 1), ('JAO', 1), ('GHAR', 1), ('PE', 1), ('MUJHE', 1), ('SIKHA', 1), ('DEGI', 1), ('😂😂😂', 1), ('\\NMUJHE', 1), ('MAZA', 1), ('AAYA', 1), ('😂😂', 1), ('HTTPS://TCO/AQRFUUJS0I', 1), ('NEKOSONA', 1), ('HTTPS://TCO/HKJZWDY1X5', 1), ('INQUIRERDOTNET:', 1), ('DIFFERENT', 1), ('SECTORS', 1), ('GATHER', 1), ('QUEZON', 1), ('CITY', 1), ('MONDAY', 1), ('JULY', 1), ('27', 1), ('HOURS', 1), ('EMERGENCY', 1), ('STRETCHED', 1), ('GOVERNMENTS', 1), ('RESOURCES', 1), ('LIMITS', 1), ('OFFICE', 1), ('WORKED', 1), ('CLOSELY', 1), ('QUICK', 1), ('HEAL', 1), ('ACT\\N\\NPRESIDENT', 1), ('JADINETRASH:', 1), ('HER', 1), ('THOUGHTS', 1), ('STYLE', 1), ('\\N\\NTHANK', 1), ('BATTLES', 1), ('FIGHT', 1), ('ALWAYS', 1), ('BEEN', 1), ('BIGGER…', 1), ('D ...

# %% [markdown]
# #### 2.2.4.
#
# Print out the top 5 words (based on count).
#
# Take note of the formatting below (i.e. one line per print output).
#
# Sample output shown below, with the index shown as the leftmost element (the integer starting with 1).
#
# Hint: No need to create a special index variable and manually increment. You may use one of the many `for` loop constructs for automatic index variable generation. You don't have to, but it's easier.

# %%
# write code here
for i in range (0,5):
    print (i+1, words_list[i])
# Out:
# 1 ('SONA', 61)
# 2 ('THE', 55)
# 3 ('RT', 53)
# 4 ('TO', 34)
# 5 ('SA', 34)

# %% [markdown]
# #### 2.2.5.
#
# Write a new **csv** file `wordcount.csv` with format like so:
#
# ```
# word,count
# SONA,66
# THE,56
# RT,54
# TO,37
# SA,35
# ...
# ```
#
# Hint: You may use plain old string concatenation for writing to file, but feel free to experiment with other options.

# %%
import csv

# write code here
with open('wordcount.csv', 'w', encoding = 'utf-8') as wordfile:
    # write the rest of your code here
    csvwriter = csv.writer(wordfile)
    field_names = ['word', 'count']
    writer = csv.DictWriter(wordfile,fieldnames = field_names)
    writer.writeheader
    
    for i in words_list:
        csvwriter.writerow(i)

# %% [markdown]
# Perform a `diff` or `fc` operation between your output file and the file named `wordcount-test.csv` which you can download from Canvas. Make sure there are no differences.
#
# **IMPORTANT:** Please make sure that you commit `wordcount.csv` together with your Jupyter Notebook in your GitHub repository.
